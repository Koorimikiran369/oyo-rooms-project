# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cleaned_Data.csv',index_col=0)

# %%
df
# Out:
#                                                    Original_price  Offer  \
# Name
# OYO 22085 Raj Banjara White House                          2459.0   32.0
# Collection O 42514 Venkat Nagar                            3158.0   32.0
# Capital O 44354 Jubilee Banjara Suites                     1778.0   32.0
# OYO 35487 Hotel Meena Grand                                2090.0   32.0
# OYO 16018 Rainbow Saphire                                  2607.0   32.0
# Collection O 46198 New Sree Krishna                        3964.0   32.0
# OYO 14224 Happy Guest house                                2373.0   32.0
# OYO 62547 Dream Connect Stays                              1941.0   32.0
# OYO 11376 Golden Park                                      2205.0   45.0
# OYO 11316 Athithi Inn                                      2178.0   38.0
# OYO 10272 Hotel Ruma                                       1777.0   32.0
# OYO 18725 Sr Grand                                         1910.0   32.0
# ...

# %% [markdown]
# # City

# %% [markdown]
# ## City vs Location

# %%
df[(df['City']=='Hyderabad')]['Location'].value_counts()
# Out:
# Jubilee Hills                         180
# Banjara Hills                         180
# Lakdikapool                           160
# Begumpet                              160
# Madhapur                              140
# Secunderabad Railway Station          140
# Mehdipatnam                           140
# Ameerpet                              140
# Hitech City                           140
# Nampally                              140
# LB Nagar                              140
# Himayathnagar                         140
# Kukatpally                            120
# Kondapur                              120
# Kachiguda Railway Station             100
# Gachibowli                            100
# Miyapur                                80
# Uppal                                  40
# Shamshabad                             40
# Rajiv Gandhi International Airport     40
# Name: Location, dtype: int64

# %%
df[(df['City']=='Hyderabad')]['Location'].value_counts().plot.bar()

# %% [markdown]
# ### Observations
#
# - In Hyderabad, Jubilee Hills and Banjara Hills have the maximum number of hotels.
# - In Hyderabad, Uppal, Rajiv Gandhi International Airport and Shamshabad have the least number of hotels.

# %%
df[(df['City']=='Bangalore')]['Location'].value_counts()
# Out:
# MG Road                             240
# Jayanagar                           200
# Domlur                              200
# Indiranagar                         180
# BTM 2ndStage                        180
# Jp Nagar                            180
# Majestic City Railway Station       180
# Koramangala                         180
# Majestic                            180
# Kalyan Nagar                        160
# Hebbal                              140
# HSR Layout                          140
# Rajaji Nagar                        140
# Yeshwanthpur                        100
# Yelahanka                            80
# Marathahalli                         60
# Kempagowda International Airport     60
# KR Puram                             60
# Electronic City                      40
# Whitefield                           20
# Name: Location, dtype: int64

# %%
df[(df['City']=='Bangalore')]['Location'].value_counts().plot.bar()

# %% [markdown]
# ### Observations
#
# - In Bangalore, MG Road has the highest number of hotels.
# - In Bangalore, Whitefield has the least number of hotels.

# %% [markdown]
# ## City vs Summary

# %%
df[(df['City']=='Hyderabad')]['Summary'].value_counts()
# Out:
# Very Good               1092
# Good                     519
# Excellent                476
# Fair                     211
# Yet to be summarised     134
# Fabulous                   8
# Name: Summary, dtype: int64

# %%
df[(df['City']=='Hyderabad')]['Summary'].value_counts().plot.bar()

# %% [markdown]
# ### Observation
#
# - More than 1000 properties are very good in Hyderabad

# %%
df[(df['City']=='Bangalore')]['Summary'].value_counts()
# Out:
# Very Good               1267
# Good                     582
# Excellent                482
# Yet to be summarised     219
# Fair                     155
# Fabulous                  15
# Name: Summary, dtype: int64

# %%
df[(df['City']=='Bangalore')]['Summary'].value_counts().plot.bar()

# %% [markdown]
# ### Observation
#
# - More than 1200 properties are Very Good in Bangalore.

# %% [markdown]
# # CITY VS FINAL_PRICE

# %%
sns.barplot(x='City',y='Final_price',data=df)

# %%
df[df['City']=='Hyderabad']['Final_price'].max()
# Out:
# 8170.0

# %%
df[(df['City']=='Hyderabad')&(df['Final_price']==8170)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# Capital O 22737 Chandra Grand Hotel         11983.0   32.0       8170.0
# Capital O 22737 Chandra Grand Hotel         11983.0   32.0       8170.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# Capital O 22737 Chandra Grand Hotel       6.0     3.8             661.0
# Capital O 22737 Chandra Grand Hotel      12.0     3.8             661.0
#
#                                     Summary                      Location  \
# Name
# Capital O 22737 Chandra Grand Hotel    Good  Secunderabad Railway Station
# Capital O 22737 Chandra Grand Hotel    Good                      LB Nagar
#
#                                           City
# Name
# Capital O 22737 Chandra Grand Hotel  Hyderabad
# Capital O 22737 Chandra Grand Hotel  Hyderabad

# %%
df[df['City']=='Hyderabad']['Final_price'].min()
# Out:
# 440.0

# %%
df[(df['City']=='Hyderabad')&(df['Final_price']==440)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 45127 Thirumala Lodge SPOT                645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# ...

# %%
df[df['City']=='Bangalore']['Final_price'].max()
# Out:
# 20651.0

# %%
df[(df['City']=='Bangalore')&(df['Final_price']==20651)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# Palette - Prestige Golfshire Club         32452.0   36.0      20651.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# Palette - Prestige Golfshire Club      12.0     0.0               0.0
#
#                                                 Summary  \
# Name
# Palette - Prestige Golfshire Club  Yet to be summarised
#
#                                                            Location       City
# Name
# Palette - Prestige Golfshire Club  Kempagowda International Airport  Bangalore

# %%
df[df['City']=='Bangalore']['Final_price'].min()
# Out:
# 440.0

# %%
df[(df['City']=='Bangalore')&(df['Final_price']==440)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# SPOT ON 47596 Gayatri Comforts SPOT           645.0   32.0        440.0
# SPOT ON 47596 Gayatri Comforts SPOT           645.0   32.0        440.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 47596 Gayatri Comforts SPOT      10.0     3.9             314.0
# SPOT ON 47596 Gayatri Comforts SPOT       0.4     3.9             314.0
#
#                                     Summary   Location       City
# Name
# SPOT ON 47596 Gayatri Comforts SPOT    Good     Hebbal  Bangalore
# SPOT ON 47596 Gayatri Comforts SPOT    Good  Yelahanka  Bangalore

# %%
sns.barplot(x='City',y='Original_price',data=df)

# %%
df[df['City']=='Hyderabad']['Original_price'].max()
# Out:
# 11983.0

# %%
df[(df['City']=='Hyderabad')&(df['Original_price']==11983)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# Capital O 22737 Chandra Grand Hotel         11983.0   32.0       8170.0
# Capital O 22737 Chandra Grand Hotel         11983.0   32.0       8170.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# Capital O 22737 Chandra Grand Hotel       6.0     3.8             661.0
# Capital O 22737 Chandra Grand Hotel      12.0     3.8             661.0
#
#                                     Summary                      Location  \
# Name
# Capital O 22737 Chandra Grand Hotel    Good  Secunderabad Railway Station
# Capital O 22737 Chandra Grand Hotel    Good                      LB Nagar
#
#                                           City
# Name
# Capital O 22737 Chandra Grand Hotel  Hyderabad
# Capital O 22737 Chandra Grand Hotel  Hyderabad

# %%
df[df['City']=='Bangalore']['Original_price'].max()
# Out:
# 32452.0

# %%
df[(df['City']=='Bangalore')&(df['Original_price']==32452)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# Palette - Prestige Golfshire Club         32452.0   36.0      20651.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# Palette - Prestige Golfshire Club      12.0     0.0               0.0
#
#                                                 Summary  \
# Name
# Palette - Prestige Golfshire Club  Yet to be summarised
#
#                                                            Location       City
# Name
# Palette - Prestige Golfshire Club  Kempagowda International Airport  Bangalore

# %%
df[df['City']=='Hyderabad']['Original_price'].min()
# Out:
# 645.0

# %%
df[(df['City']=='Hyderabad')&(df['Original_price']==645)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 45127 Thirumala Lodge SPOT                645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 48349 Sri Sai Lohith Lodge SPOT           645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# SPOT ON 65122 K-inn SPOT                          645.0   32.0        440.0
# ...

# %%
df[df['City']=='Bangalore']['Original_price'].min()
# Out:
# 645.0

# %%
df[(df['City']=='Bangalore')&(df['Original_price']==645)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# SPOT ON 47596 Gayatri Comforts SPOT           645.0   32.0        440.0
# SPOT ON 47596 Gayatri Comforts SPOT           645.0   32.0        440.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 47596 Gayatri Comforts SPOT      10.0     3.9             314.0
# SPOT ON 47596 Gayatri Comforts SPOT       0.4     3.9             314.0
#
#                                     Summary   Location       City
# Name
# SPOT ON 47596 Gayatri Comforts SPOT    Good     Hebbal  Bangalore
# SPOT ON 47596 Gayatri Comforts SPOT    Good  Yelahanka  Bangalore

# %% [markdown]
# ### Observation
#     - Mumbai has the highest Final_price and Original_price.
#
#     - Capital O 22737 Chandra Grand Hotel is the most expensive hotel in Hyderabad
#     - SPOT ON 65122 K - inn SPOT, SPOT ON 45127 Thirumala Lodge SPOT and SPOT ON 48349 Sri Sai Lohith Lodge SPOT are the cheapest hotels in Hyderabad.
#
#     - Palette -Prestige Golfshire Club is the most expensive hotel in Bangalore
#     - SPOT ON 47596 Gayatri Comforts SPOT  is the most cheapest hotel in Bangalore

# %% [markdown]
# # CITY VS OFFER

# %%
sns.barplot(x='City',y='Offer',data=df)

# %%
df[df['City']=='Hyderabad']['Offer'].describe()
# Out:
# count    2440.000000
# mean       33.416393
# std         4.459510
# min        32.000000
# 25%        32.000000
# 50%        32.000000
# 75%        32.000000
# max        63.000000
# Name: Offer, dtype: float64

# %%
df[df['City']=='Bangalore']['Offer'].describe()
# Out:
# count    2720.000000
# mean       34.656618
# std         6.536211
# min        32.000000
# 25%        32.000000
# 50%        32.000000
# 75%        32.000000
# max        70.000000
# Name: Offer, dtype: float64

# %% [markdown]
# # Observations
#
# - Delhi offers the highest offers.
# - Hyderabad offers an average of 33.5% off
# - Bangalore offers an average of 34.65% off

# %% [markdown]
# # CITY VS NUMBER_OF_RATING

# %%
sns.barplot(x='City',y='Number_of_Rating',data=df)

# %%
df[df['City']=='Hyderabad']['Number_of_Rating'].describe()
# Out:
# count    2440.000000
# mean      839.736475
# std       996.294909
# min         0.000000
# 25%       225.000000
# 50%       440.000000
# 75%      1001.000000
# max      5342.000000
# Name: Number_of_Rating, dtype: float64

# %%
df[df['City']=='Bangalore']['Number_of_Rating'].describe()
# Out:
# count    2720.000000
# mean      610.291176
# std       834.700058
# min         0.000000
# 25%       130.000000
# 50%       309.000000
# 75%       719.000000
# max      6803.000000
# Name: Number_of_Rating, dtype: float64

# %% [markdown]
# ### Observation
#
# - Hyderabad has the highest number of ratings.
# - Number of Ratings for hotels in hyderabad are at a mean of 839.73
# - Number of Ratings for hotels in bangalore are at a mean of 610.29

# %% [markdown]
# # CITY VS RATING

# %%
sns.barplot(x='City',y='Rating',data=df)

# %%
df[df['City']=='Hyderabad']['Rating'].max()
# Out:
# 4.9

# %%
df[(df['City']=='Hyderabad')&(df['Rating']==4.9)]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       7.8     4.9
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       3.1     4.9
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       2.7     4.9
# ...

# %%
df[df['City']=='Bangalore']['Rating'].max()
# Out:
# 5.0

# %%
df[(df['City']=='Bangalore')&(df['Rating']==5.0)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 29020 Vm Comfort              2313.0   32.0       1577.0      17.0
# OYO 24130 Surya Comforts          1667.0   41.0        990.0      17.0
# Palette - Npg Hotel               2861.0   32.0       1951.0       9.5
# OYO 29020 Vm Comfort              2313.0   32.0       1577.0       9.2
# OYO 19285 Uv Comforts             1892.0   32.0       1290.0       8.0
# OYO 29020 Vm Comfort              2313.0   32.0       1577.0       9.1
# OYO 19285 Uv Comforts             1892.0   32.0       1290.0       6.6
# OYO 29020 Vm Comfort              2313.0   32.0       1577.0       1.8
# OYO 19285 Uv Comforts             1892.0   32.0       1290.0       6.7
# Palette - Npg Hotel               2861.0   32.0       1951.0       9.2
# OYO 19285 Uv Comforts             1892.0   32.0       1290.0       8.4
#
#                           Rating  Number_of_Rating   Summary  \
# Name
# ...

# %%
df[df['City']=='Hyderabad']['Rating'].describe()
# Out:
# count    2440.000000
# mean        3.881680
# std         1.018929
# min         0.000000
# 25%         3.800000
# 50%         4.200000
# 75%         4.400000
# max         4.900000
# Name: Rating, dtype: float64

# %%
df[df['City']=='Bangalore']['Rating'].describe()
# Out:
# count    2720.000000
# mean        3.786801
# std         1.178425
# min         0.000000
# 25%         3.800000
# 50%         4.100000
# 75%         4.400000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ### Observation
#
# - From the bar graph it can be infered that mean of the ratings of hotels is the highest in INDIA.
# - In Hyderabad, OYO 14501 Hotel Hill View Guest House Begumpet is the highest rated hotel.
# - In Bangalore, OYO 19285 Uv Comforts, Palette - Npg Hotel, OYO 29020 Vm Comfort and OYO 24130 Surya Comforts are rated the highest.

# %% [markdown]
# # CITY VS DISTANCE

# %%
sns.barplot(x='City',y='Distance',data=df)

# %%
df[df['City']=='Hyderabad']['Distance'].min()
# Out:
# 0.1

# %%
df[(df['City']=='Hyderabad')&(df['Distance']==0.1)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 47332 Hotel Dolphin                    1481.0   32.0       1010.0
# OYO 9303 Celebrity Skyhy Rooms             3180.0   32.0       2168.0
# OYO 14731 Hallmark Inn Kukatpally          6592.0   32.0       4495.0
# OYO 2840 Kanha Grand                       1481.0   32.0       1010.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 47332 Hotel Dolphin                 0.1     4.4             279.0
# OYO 9303 Celebrity Skyhy Rooms          0.1     3.9             245.0
# OYO 14731 Hallmark Inn Kukatpally       0.1     3.9             466.0
# OYO 2840 Kanha Grand                    0.1     4.1             542.0
#
#                                      Summary       Location       City
# Name
# OYO 47332 Hotel Dolphin            Very Good  Jubilee Hills  Hyderabad
# OYO 9303 Celebrity Skyhy Rooms          Good       Begumpet  Hyderabad
# ...

# %%
df[df['City']=='Hyderabad']['Distance'].max()
# Out:
# 19.0

# %%
df[(df['City']=='Hyderabad')&(df['Distance']==19)]
# Out:
#                                                     Original_price  Offer  \
# Name
# OYO 22085 Raj Banjara White House                           2459.0   32.0
# OYO 26562 Dazzle Stays                                      1730.0   42.0
# OYO 18454 Hallmark Inn Begumpet                             2390.0   58.0
# OYO 33412 Spacious Stay Qutub Shahi Tomb                    1796.0   32.0
# OYO 46058 Pleasant Stay Near Moosapet Metro Sta...          2444.0   32.0
# OYO 12237 Luxury Villas                                     2157.0   32.0
# OYO 9386 Hotel Mannys Plaza                                 2157.0   32.0
# OYO 14501 Hotel Hill View Guest House Begumpet              2087.0   32.0
# OYO Flagship 35993 Puppalaguda                              1481.0   32.0
# Capital O 44354 Jubilee Banjara Suites                      1778.0   32.0
# OYO 8941 Hotel Golden Leaves                                2449.0   32.0
# OYO 30396 Hotel Shri Chaitra Deluxe                         2685.0   32.0
# ...

# %%
df[df['City']=='Bangalore']['Distance'].min()
# Out:
# 0.1

# %%
df[(df['City']=='Bangalore')&(df['Distance']==0.1)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 47451 Elegant Indira Nagar           3058.0   32.0       2085.0       0.1
# OYO 13594 Mathrushree Residency          6584.0   32.0       4489.0       0.1
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 47451 Elegant Indira Nagar      4.1              98.0  Very Good
# OYO 13594 Mathrushree Residency     4.5              50.0  Excellent
#
#                                      Location       City
# Name
# OYO 47451 Elegant Indira Nagar    Indiranagar  Bangalore
# OYO 13594 Mathrushree Residency  Rajaji Nagar  Bangalore

# %%
df[df['City']=='Bangalore']['Distance'].max()
# Out:
# 19.0

# %%
df[(df['City']=='Bangalore')&(df['Distance']==19)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 40115 J P Palace                       1878.0   32.0       1281.0
# Capital O 49358 Blue Meridian Inn         11185.0   32.0       7627.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 40115 J P Palace                   19.0     4.8             481.0
# Capital O 49358 Blue Meridian Inn      19.0     4.4             440.0
#
#                                      Summary  \
# Name
# OYO 40115 J P Palace               Excellent
# Capital O 49358 Blue Meridian Inn  Very Good
#
#                                                            Location       City
# Name
# OYO 40115 J P Palace               Kempagowda International Airport  Bangalore
# Capital O 49358 Blue Meridian Inn  Kempagowda International Airport  Bangalore

# %% [markdown]
# ### Observation
#
# - Least distance from the location can be observed in the data from Chennai.
#
# - In Bangalore, Hotels with maximum distance from the specified location are Capital O 49358 Blue Meridian Inn and OYO 40115 J P Palace.
#
# - In Bangalore, Hotels with minimum distance from the specified location are OYO 13594 Mathrushree Residency and  OYO 47451 Elegant Indira Nagar
#
# - In Hyderabad, Hotels with maximum distance from the speccified location are in the locations of Shamshabad, LB Nagar and a couple in Rajiv Gandhi International Airport.
#
# - In Hyderabad, Hotels with minimum distance from the specified location are OYO 47332 Hotel Dolphin, OYO 9303 Celebrity Skyhy Rooms, OYO 14731 Hallmark Inn Kukatpally and OYO 2840 Kanha Grand.
