# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['Multivariate Analysis.ipynb',
#  'Mumbai',
#  'Bivariate original.ipynb',
#  'Bangalore',
#  'Hyderabad.csv',
#  'Delhi.csv',
#  '.DS_Store',
#  'Chennai.csv',
#  'Mumbai.csv',
#  'Data_Cleaning.ipynb',
#  'Hyderabad',
#  'Chennai',
#  'Final_Dataset.csv',
#  'Delhi',
#  'Bivariate Analysis.ipynb',
#  'Cleaned_data.csv',
#  'Data_Understanding.ipynb',
#  'Bangalore.csv',
#  'Final_Dataset.ipynb',
#  '.ipynb_checkpoints',
#  'Univariate Analysis.ipynb',
#  'project data analysis multi.ipynb']

# %%
df=pd.read_csv('Cleaned_Data.csv',index_col=0)
df
# Out:
#                                                    Original_price  Offer  \
# Name
# OYO 22085 Raj Banjara White House                          2459.0   32.0
# Collection O 42514 Venkat Nagar                            3158.0   32.0
# Capital O 44354 Jubilee Banjara Suites                     1778.0   32.0
# OYO 35487 Hotel Meena Grand                                2090.0   32.0
# OYO 16018 Rainbow Saphire                                  2607.0   32.0
# Collection O 46198 New Sree Krishna                        3964.0   32.0
# OYO 14224 Happy Guest house                                2373.0   32.0
# OYO 62547 Dream Connect Stays                              1941.0   32.0
# OYO 11376 Golden Park                                      2205.0   45.0
# OYO 11316 Athithi Inn                                      2178.0   38.0
# OYO 10272 Hotel Ruma                                       1777.0   32.0
# OYO 18725 Sr Grand                                         1910.0   32.0
# ...

# %%
b=df[df['City']=='Bangalore']

# %%
b
# Out:
#                                                Original_price  Offer  \
# Name
# OYO 9925 The Ocea International                        2268.0   35.0
# OYO 422 Tiny Tap Rooms                                 2175.0   35.0
# OYO 36197 Royal Wood                                   2021.0   33.0
# OYO 649 Hotel Ajantha Trinity Inn                      1868.0   32.0
# OYO 24093 Kp Suits                                     2090.0   32.0
# OYO 10136 Hotel Central Suites                         2923.0   52.0
# OYO 48370 Enticing Stay Kalyan Nagar                   2536.0   32.0
# OYO 13567 1BHK Suites and Rooms                        2341.0   32.0
# OYO Townhouse 258 Bellandur                            2362.0   32.0
# OYO 7897 Status Suites Suite                           2253.0   32.0
# Collection O 30067 Indiranagar                         3132.0   32.0
# OYO Townhouse 238 Ulsoor                               3187.0   32.0
# ...

# %% [markdown]
# # BANGALORE

# %%
b['Location'].unique()
# Out:
# array(['Indiranagar', 'Domlur', 'Majestic', 'Jayanagar', 'Whitefield',
#        'Majestic City Railway Station',
#        'Kempagowda International Airport', 'Kalyan Nagar', 'Rajaji Nagar',
#        'Hebbal', 'HSR Layout', 'Yelahanka', 'MG Road', 'KR Puram',
#        'Jp Nagar', 'Electronic City', 'Yeshwanthpur', 'Koramangala',
#        'BTM 2ndStage', 'Marathahalli'], dtype=object)

# %% [markdown]
# ## BTM_2nd_Stage

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='BTM 2ndStage']['Summary'].value_counts()
# Out:
# Very Good               86
# Good                    35
# Excellent               32
# Yet to be summarised    15
# Fair                    12
# Name: Summary, dtype: int64

# %%
b[b['Location']=='BTM 2ndStage']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.0    20
# 4.1    19
# 4.3    19
# 4.4    16
# 4.2    12
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 983.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==983)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# SPOT ON 60556 Udupi Residency SPOT          1442.0   32.0        983.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 60556 Udupi Residency SPOT       4.1     4.4             330.0
#
#                                       Summary      Location       City
# Name
# SPOT ON 60556 Udupi Residency SPOT  Very Good  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1528.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1528)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 180 Jayanagar          1481.0   32.0       1010.0       3.5
#
#                              Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 180 Jayanagar     4.4            1528.0  Very Good
#
#                                  Location       City
# Name
# OYO Townhouse 180 Jayanagar  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.8

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.8)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 49646 Hotel Champion Paradise          1925.0   32.0       1312.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 49646 Hotel Champion Paradise       1.8     4.4             334.0
#
#                                            Summary      Location       City
# Name
# Capital O 49646 Hotel Champion Paradise  Very Good  BTM 2ndStage  Bangalore

# %% [markdown]
# # Excellent

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 755.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Final_price']==755)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1107.0   32.0        755.0       8.1
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                      Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2662.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2662)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       2.8     4.5            2662.0
#
#                                      Summary      Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.9

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Distance']==0.9)]
# Out:
#                                           Original_price  Offer  Final_price  \
# Name
# OYO 47142 Luxurious Stay Apollo Hospital          2077.0   32.0       1417.0
#
#                                           Distance  Rating  Number_of_Rating  \
# Name
# OYO 47142 Luxurious Stay Apollo Hospital       0.9     4.5             391.0
#
#                                             Summary      Location       City
# Name
# OYO 47142 Luxurious Stay Apollo Hospital  Excellent  BTM 2ndStage  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    14
# 4.6    11
# 4.7     5
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 975.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.6)&(b['Final_price']==1010)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 10363 Sri Balaji Guest House          1489.0   32.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 10363 Sri Balaji Guest House       4.8     4.6             619.0
#
#                                     Summary      Location       City
# Name
# OYO 10363 Sri Balaji Guest House  Excellent  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.6)]['Number_of_Rating'].max()
# Out:
# 2228.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.6)&(b['Number_of_Rating']==2228)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# Collection O 42670 Grand Continent          2780.0   32.0       1896.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# Collection O 42670 Grand Continent       2.0     4.6            2228.0
#
#                                       Summary      Location       City
# Name
# Collection O 42670 Grand Continent  Excellent  BTM 2ndStage  Bangalore

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.6)]['Distance'].min()
# Out:
# 1.0

# %%
b[(b['Location']=='BTM 2ndStage')&(b['Summary']=='Excellent')&(b['Rating']==4.6)&(b['Distance']==1.0)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO Home 64412 Peaceful Stay Bg Road          1777.0   32.0       1212.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO Home 64412 Peaceful Stay Bg Road       1.0     4.6             168.0
#
#                                         Summary      Location       City
# Name
# OYO Home 64412 Peaceful Stay Bg Road  Excellent  BTM 2ndStage  Bangalore

# %% [markdown]
# ## Domlur

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Domlur']['Summary'].value_counts()
# Out:
# Very Good               91
# Good                    48
# Excellent               35
# Fair                    13
# Yet to be summarised    13
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Domlur']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    24
# 4.0    23
# 4.4    16
# 4.1    15
# 4.2    13
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 983.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==983)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# SPOT ON 60556 Udupi Residency SPOT          1442.0   32.0        983.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 60556 Udupi Residency SPOT       3.8     4.4             330.0
#
#                                       Summary Location       City
# Name
# SPOT ON 60556 Udupi Residency SPOT  Very Good   Domlur  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       4.4
#
#                                 Rating  Number_of_Rating    Summary Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good   Domlur
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 0.4

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==0.4)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 255 Indiranagar Double Road          2508.0   32.0       1710.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 255 Indiranagar Double Road       0.4     4.4             114.0
#
#                                              Summary Location       City
# Name
# OYO Townhouse 255 Indiranagar Double Road  Very Good   Domlur  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 975.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Final_price']==975)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15016 Hotel City Plaza          1819.0   46.0        975.0       6.3
#
#                             Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 15016 Hotel City Plaza     4.8             437.0  Excellent   Domlur
#
#                                  City
# Name
# OYO 15016 Hotel City Plaza  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2481.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2481)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 25030 D'brooks          2956.0   32.0       2016.0       9.7
#
#                           Rating  Number_of_Rating    Summary Location  \
# Name
# Capital O 25030 D'brooks     4.5            2481.0  Excellent   Domlur
#
#                                City
# Name
# Capital O 25030 D'brooks  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.7

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Distance']==0.7)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 829 Garden Green          2099.0   32.0       1432.0       0.7     4.6
#
#                       Number_of_Rating    Summary Location       City
# Name
# OYO 829 Garden Green             161.0  Excellent   Domlur  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    15
# 4.6    13
# 4.8     5
# 4.7     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 975.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==975)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15016 Hotel City Plaza          1819.0   46.0        975.0       6.3
#
#                             Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 15016 Hotel City Plaza     4.8             437.0  Excellent   Domlur
#
#                                  City
# Name
# OYO 15016 Hotel City Plaza  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 1763.0

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==1763)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       6.2     4.8            1763.0
#
#                                            Summary Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent   Domlur  Bangalore

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 6.2

# %%
b[(b['Location']=='Domlur')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==6.2)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       6.2     4.8            1763.0
#
#                                            Summary Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent   Domlur  Bangalore

# %% [markdown]
# ## Electronic_City

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Electronic City']['Summary'].value_counts()
# Out:
# Very Good               25
# Good                     5
# Yet to be summarised     4
# Excellent                4
# Fair                     2
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Electronic City']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    7
# 4.4    6
# 4.2    5
# 4.0    4
# 4.1    3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1010.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1010)]
# Out:
#                                                     Original_price  Offer  \
# Name
# SilverKey Executive Stays 24644 Electronic City...          1481.0   32.0
#
#                                                     Final_price  Distance  \
# Name
# SilverKey Executive Stays 24644 Electronic City...       1010.0       3.8
#
#                                                     Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 24644 Electronic City...     4.4            2086.0
#
#                                                       Summary  \
# Name
# SilverKey Executive Stays 24644 Electronic City...  Very Good
#
#                                                            Location       City
# Name
# SilverKey Executive Stays 24644 Electronic City...  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2086.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==2086)]
# Out:
#                                                     Original_price  Offer  \
# Name
# SilverKey Executive Stays 24644 Electronic City...          1481.0   32.0
#
#                                                     Final_price  Distance  \
# Name
# SilverKey Executive Stays 24644 Electronic City...       1010.0       3.8
#
#                                                     Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 24644 Electronic City...     4.4            2086.0
#
#                                                       Summary  \
# Name
# SilverKey Executive Stays 24644 Electronic City...  Very Good
#
#                                                            Location       City
# Name
# SilverKey Executive Stays 24644 Electronic City...  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 2.9

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==2.9)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 8480 A2B Electronic City          2468.0   32.0       1683.0       2.9
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 8480 A2B Electronic City     4.4             326.0  Very Good
#
#                                      Location       City
# Name
# OYO 8480 A2B Electronic City  Electronic City  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 710.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Final_price']==710)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                         Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 459.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==459)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                         Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.9

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Distance']==0.9)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 451 Goyal Residency          1903.0   32.0       1297.0       0.9     4.5
#
#                          Number_of_Rating    Summary         Location  \
# Name
# OYO 451 Goyal Residency             244.0  Excellent  Electronic City
#
#                               City
# Name
# OYO 451 Goyal Residency  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    3
# 4.7    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Final_price'].min()
# Out:
# 710.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Final_price']==710)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                         Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Number_of_Rating'].max()
# Out:
# 459.0

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Number_of_Rating']==459)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                         Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Electronic City  Bangalore

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Distance'].min()
# Out:
# 3.4

# %%
b[(b['Location']=='Electronic City')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Distance']==3.4)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                         Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Electronic City  Bangalore

# %% [markdown]
# # Hebbal

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Hebbal']['Summary'].value_counts()
# Out:
# Very Good               65
# Good                    28
# Excellent               21
# Yet to be summarised    14
# Fair                     9
# Fabulous                 3
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Hebbal']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    17
# 4.4    15
# 4.1    13
# 4.2    11
# 4.0     9
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 655.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==655)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT           961.0   32.0        655.0       7.2
#
#                               Rating  Number_of_Rating    Summary Location  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT     4.4             429.0  Very Good   Hebbal
#
#                                    City
# Name
# SPOT ON 47215 Jp Hotel  SPOT  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       9.9
#
#                                 Rating  Number_of_Rating    Summary Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good   Hebbal
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.4

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.4)]
# Out:
#                  Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 2388 Hebbal          2460.0   32.0       1678.0       1.4     4.4
#
#                  Number_of_Rating    Summary Location       City
# Name
# OYO 2388 Hebbal             134.0  Very Good   Hebbal  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 951.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Final_price']==951)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 30686 G K Residency          1394.0   32.0        951.0       8.9     4.7
#
#                          Number_of_Rating    Summary Location       City
# Name
# OYO 30686 G K Residency             283.0  Excellent   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       5.5
#
#                                Rating  Number_of_Rating    Summary Location  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent   Hebbal
#
#                                     City
# Name
# Capital O 37517 Withinn Hotel  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 2.7

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Distance']==2.7)]
# Out:
#                     Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 5150 Varcity s          1853.0   32.0       1264.0       2.7     4.6
#
#                     Number_of_Rating    Summary Location       City
# Name
# OYO 5150 Varcity s             303.0  Excellent   Hebbal  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    11
# 4.5     6
# 4.7     3
# 4.8     1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 2664.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==2664)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       5.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                               Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 271.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==271)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       5.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                               Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 5.9

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==5.9)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       5.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                               Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites   Hebbal  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.6     5.0
#
#                        Number_of_Rating   Summary Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 109.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==109)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       2.0
#
#                             Rating  Number_of_Rating   Summary Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous   Hebbal
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 2.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Distance']==2.0)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       2.0
#
#                             Rating  Number_of_Rating   Summary Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous   Hebbal
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 5.0    2
# 4.9    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.6     5.0
#
#                        Number_of_Rating   Summary Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Number_of_Rating'].max()
# Out:
# 1.0

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Number_of_Rating']==1)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 29020 Vm Comfort           2313.0   32.0       1577.0       9.1     5.0
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.6     5.0
#
#                        Number_of_Rating   Summary Location       City
# Name
# OYO 29020 Vm Comfort                1.0  Fabulous   Hebbal  Bangalore
# OYO 19285 Uv Comforts               1.0  Fabulous   Hebbal  Bangalore

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Distance'].min()
# Out:
# 6.6

# %%
b[(b['Location']=='Hebbal')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Distance']==6.6)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.6     5.0
#
#                        Number_of_Rating   Summary Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous   Hebbal  Bangalore

# %% [markdown]
# # Hsr_layout

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='HSR Layout']['Summary'].value_counts()
# Out:
# Very Good               71
# Good                    28
# Excellent               26
# Yet to be summarised     9
# Fair                     6
# Name: Summary, dtype: int64

# %%
b[b['Location']=='HSR Layout']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    16
# 4.3    16
# 4.0    15
# 4.1    13
# 4.2    11
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 903.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==903)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1324.0   32.0        903.0
# OYO 23427 Ashrey Comforts                  1324.0   32.0        903.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       7.8     4.4            1528.0
# OYO 23427 Ashrey Comforts               7.1     4.4             356.0
#
#                                      Summary    Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  HSR Layout  Bangalore
# OYO 23427 Ashrey Comforts          Very Good  HSR Layout  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2086.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==2086)]
# Out:
#                                                     Original_price  Offer  \
# Name
# SilverKey Executive Stays 24644 Electronic City...          1481.0   32.0
#
#                                                     Final_price  Distance  \
# Name
# SilverKey Executive Stays 24644 Electronic City...       1010.0       9.3
#
#                                                     Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 24644 Electronic City...     4.4            2086.0
#
#                                                       Summary    Location  \
# Name
# SilverKey Executive Stays 24644 Electronic City...  Very Good  HSR Layout
#
#                                                          City
# Name
# SilverKey Executive Stays 24644 Electronic City...  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 0.8

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==0.8)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# OYO 45366 Elite Stay HSR Club          2957.0   32.0       2017.0       0.8
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# OYO 45366 Elite Stay HSR Club     4.4             727.0  Very Good
#
#                                  Location       City
# Name
# OYO 45366 Elite Stay HSR Club  HSR Layout  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 1005.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Final_price']==1005)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Home 61518 Exotic Stay Bg Road          1474.0   32.0       1005.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Home 61518 Exotic Stay Bg Road       5.7     4.8             110.0
#
#                                       Summary    Location       City
# Name
# OYO Home 61518 Exotic Stay Bg Road  Excellent  HSR Layout  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2662.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2662)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       7.2     4.5            2662.0
#
#                                      Summary    Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  HSR Layout  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.5

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Distance']==0.5)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 4428 Central Platinum Suites          2680.0   35.0       1746.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 4428 Central Platinum Suites       0.5     4.5             149.0
#
#                                     Summary    Location       City
# Name
# OYO 4428 Central Platinum Suites  Excellent  HSR Layout  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    11
# 4.6     9
# 4.7     4
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1005.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1005)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Home 61518 Exotic Stay Bg Road          1474.0   32.0       1005.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Home 61518 Exotic Stay Bg Road       5.7     4.8             110.0
#
#                                       Summary    Location       City
# Name
# OYO Home 61518 Exotic Stay Bg Road  Excellent  HSR Layout  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 437.0

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==437)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       5.7     4.8             437.0
#
#                                     Summary    Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  HSR Layout  Bangalore

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 5.7

# %%
b[(b['Location']=='HSR Layout')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==5.7)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver            1716.0   41.0       1010.0
# OYO Home 61518 Exotic Stay Bg Road          1474.0   32.0       1005.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver         5.7     4.8             437.0
# OYO Home 61518 Exotic Stay Bg Road       5.7     4.8             110.0
#
#                                       Summary    Location       City
# Name
# OYO 15016 Hotel City Plaza Saver    Excellent  HSR Layout  Bangalore
# OYO Home 61518 Exotic Stay Bg Road  Excellent  HSR Layout  Bangalore

# %% [markdown]
# # Indiranagar

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Indiranagar']['Summary'].value_counts()
# Out:
# Very Good               85
# Good                    41
# Excellent               33
# Yet to be summarised    11
# Fair                    10
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Indiranagar']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    19
# 4.0    18
# 4.1    17
# 4.2    16
# 4.4    15
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 932.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==932)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1367.0   32.0        932.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       8.9     4.4            1528.0
#
#                                      Summary     Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       2.4
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good
#
#                                    Location       City
# Name
# Collection O 30067 Indiranagar  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.6

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.6)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 255 Indiranagar Double Road          2508.0   32.0       1710.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 255 Indiranagar Double Road       1.6     4.4             114.0
#
#                                              Summary     Location       City
# Name
# OYO Townhouse 255 Indiranagar Double Road  Very Good  Indiranagar  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 966.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Final_price']==966)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 18680 Olivia Comforts Saver          1959.0   51.0        966.0       7.0
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 18680 Olivia Comforts Saver     4.5             622.0  Excellent
#
#                                     Location       City
# Name
# OYO 18680 Olivia Comforts Saver  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')]['Number_of_Rating'].min()
# Out:
# 126.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==126)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO 47143 Designer 1BHK Apollo Hospital          2378.0   32.0       1621.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO 47143 Designer 1BHK Apollo Hospital       9.5     4.6             126.0
#
#                                            Summary     Location       City
# Name
# OYO 47143 Designer 1BHK Apollo Hospital  Excellent  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 2.1

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Distance']==2.1)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# OYO 39395 Encore Suites            2125.0   32.0       1449.0       2.1
# Capital O 46966 Apollo 27          9087.0   32.0       6196.0       2.1
#
#                            Rating  Number_of_Rating    Summary     Location  \
# Name
# OYO 39395 Encore Suites       4.6             279.0  Excellent  Indiranagar
# Capital O 46966 Apollo 27     4.6             508.0  Excellent  Indiranagar
#
#                                 City
# Name
# OYO 39395 Encore Suites    Bangalore
# Capital O 46966 Apollo 27  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    15
# 4.5    13
# 4.7     3
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1010.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1010)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       8.4     4.8             437.0
#
#                                     Summary     Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 437.0

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==437)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       8.4     4.8             437.0
#
#                                     Summary     Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Indiranagar  Bangalore

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 4.8

# %%
b[(b['Location']=='Indiranagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==4.8)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       4.8     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                   Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Indiranagar  Bangalore

# %% [markdown]
# # Jayanagar

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Jayanagar']['Summary'].value_counts()
# Out:
# Very Good               89
# Good                    44
# Excellent               37
# Yet to be summarised    19
# Fair                    11
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Jayanagar']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.0    22
# 4.3    21
# 4.4    17
# 4.1    17
# 4.2    12
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 903.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==903)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1324.0   32.0        903.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       0.9     4.4            1528.0
#
#                                      Summary   Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Jayanagar  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       9.8
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good
#
#                                  Location       City
# Name
# Collection O 30067 Indiranagar  Jayanagar  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 0.9

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==0.9)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1324.0   32.0        903.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       0.9     4.4            1528.0
#
#                                      Summary   Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Jayanagar  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       7.8
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary   Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  Jayanagar
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2662.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2662)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       2.8     4.5            2662.0
#
#                                      Summary   Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  Jayanagar  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 1.5

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Distance']==1.5)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 63230 Exotica Hotels          1481.0   32.0       1010.0       1.5
#
#                           Rating  Number_of_Rating    Summary   Location  \
# Name
# OYO 63230 Exotica Hotels     4.5             218.0  Excellent  Jayanagar
#
#                                City
# Name
# OYO 63230 Exotica Hotels  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    18
# 4.6    12
# 4.7     4
# 4.8     3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1005.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1005)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Home 61518 Exotic Stay Bg Road          1474.0   32.0       1005.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Home 61518 Exotic Stay Bg Road       4.5     4.8             110.0
#
#                                       Summary   Location       City
# Name
# OYO Home 61518 Exotic Stay Bg Road  Excellent  Jayanagar  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 1763.0

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==1763)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       6.7     4.8            1763.0
#
#                                            Summary   Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent  Jayanagar  Bangalore

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 4.3

# %%
b[(b['Location']=='Jayanagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==4.3)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       4.3     4.8             437.0
#
#                                     Summary   Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Jayanagar  Bangalore

# %% [markdown]
# # JP_nagar

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Jp Nagar']['Summary'].value_counts()
# Out:
# Very Good               81
# Good                    40
# Excellent               32
# Yet to be summarised    17
# Fair                    10
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Jp Nagar']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    20
# 4.0    20
# 4.1    17
# 4.4    13
# 4.2    11
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 903.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==903)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1324.0   32.0        903.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       3.3     4.4            1528.0
#
#                                      Summary  Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Jp Nagar  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1528.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1528)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1324.0   32.0        903.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       3.3     4.4            1528.0
#
#                                      Summary  Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Jp Nagar  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 0.7

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==0.7)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 49646 Hotel Champion Paradise          1925.0   32.0       1312.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 49646 Hotel Champion Paradise       0.7     4.4             334.0
#
#                                            Summary  Location       City
# Name
# Capital O 49646 Hotel Champion Paradise  Very Good  Jp Nagar  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       9.1
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary  Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  Jp Nagar
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2662.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2662)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       0.9     4.5            2662.0
#
#                                      Summary  Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  Jp Nagar  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.9

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Distance']==0.9)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       0.9     4.5            2662.0
#
#                                      Summary  Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  Jp Nagar  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    16
# 4.6     8
# 4.7     6
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 975.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==975)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15016 Hotel City Plaza          1819.0   46.0        975.0       5.0
#
#                             Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 15016 Hotel City Plaza     4.8             437.0  Excellent  Jp Nagar
#
#                                  City
# Name
# OYO 15016 Hotel City Plaza  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 437.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==437)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15016 Hotel City Plaza          1819.0   46.0        975.0       5.0
#
#                             Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 15016 Hotel City Plaza     4.8             437.0  Excellent  Jp Nagar
#
#                                  City
# Name
# OYO 15016 Hotel City Plaza  Bangalore

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 5.0

# %%
b[(b['Location']=='Jp Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==5.0)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15016 Hotel City Plaza          1819.0   46.0        975.0       5.0
#
#                             Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 15016 Hotel City Plaza     4.8             437.0  Excellent  Jp Nagar
#
#                                  City
# Name
# OYO 15016 Hotel City Plaza  Bangalore

# %% [markdown]
# # Kalyan_Nagar

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Kalyan Nagar']['Summary'].value_counts()
# Out:
# Very Good               77
# Good                    30
# Excellent               27
# Yet to be summarised    13
# Fair                    10
# Fabulous                 3
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Kalyan Nagar']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    18
# 4.4    17
# 4.1    15
# 4.2    14
# 4.0    13
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1000.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1000)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# OYO 14424 Saarang Forever          1906.0   48.0       1000.0       9.5
#
#                            Rating  Number_of_Rating    Summary      Location  \
# Name
# OYO 14424 Saarang Forever     4.4             377.0  Very Good  Kalyan Nagar
#
#                                 City
# Name
# OYO 14424 Saarang Forever  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       5.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good
#
#                                     Location       City
# Name
# Collection O 30067 Indiranagar  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 0.9

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==0.9)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 10232 Hotel Ashberry          7772.0   32.0       5299.0       0.9
#
#                           Rating  Number_of_Rating    Summary      Location  \
# Name
# OYO 10232 Hotel Ashberry     4.4             282.0  Very Good  Kalyan Nagar
#
#                                City
# Name
# OYO 10232 Hotel Ashberry  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 974.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Final_price']==974)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 25036 Suraksha Residency          1460.0   33.0        974.0       8.7
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 25036 Suraksha Residency     4.6             606.0  Excellent
#
#                                   Location       City
# Name
# OYO 25036 Suraksha Residency  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       8.6
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent
#
#                                    Location       City
# Name
# Capital O 37517 Withinn Hotel  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.3

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Distance']==0.3)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# OYO 13670 Skylark Service Apartment          1854.0   35.0       1212.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# OYO 13670 Skylark Service Apartment       0.3     4.7             255.0
#
#                                        Summary      Location       City
# Name
# OYO 13670 Skylark Service Apartment  Excellent  Kalyan Nagar  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    14
# 4.5     7
# 4.7     3
# 4.8     3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1848.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1848)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       9.3
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                    Location       City
# Name
# Capital O 1324 Silicon Hearth  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 1763.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==1763)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       7.3     4.8            1763.0
#
#                                            Summary      Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 0.8

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==0.8)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       0.8     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                    Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Kalyan Nagar  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.0     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 109.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==109)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       5.8
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Kalyan Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 5.8

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Distance']==5.8)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       5.8
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Kalyan Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 5.0    2
# 4.9    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.0     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Number_of_Rating'].max()
# Out:
# 1.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Number_of_Rating']==1)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 29020 Vm Comfort           2313.0   32.0       1577.0       9.2     5.0
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.0     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 29020 Vm Comfort                1.0  Fabulous  Kalyan Nagar  Bangalore
# OYO 19285 Uv Comforts               1.0  Fabulous  Kalyan Nagar  Bangalore

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Distance'].min()
# Out:
# 8.0

# %%
b[(b['Location']=='Kalyan Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Distance']==8.0)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.0     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Kalyan Nagar  Bangalore

# %% [markdown]
# # Kempagowda_International_Airport

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Kempagowda International Airport']['Summary'].value_counts()
# Out:
# Very Good               23
# Excellent               12
# Yet to be summarised     9
# Good                     8
# Fair                     5
# Fabulous                 3
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Kempagowda International Airport']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.2    8
# 4.3    6
# 4.0    4
# 4.4    3
# 4.1    2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 862.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==862)]
# Out:
#                                                   Original_price  Offer  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver          1263.0   32.0
#
#                                                   Final_price  Distance  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver        862.0       9.3
#
#                                                   Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver     4.4            1325.0
#
#                                                     Summary  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Very Good
#
#                                                                           Location  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Kempagowda International Airport
#
#                                                        City
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1325.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1325)]
# Out:
#                                                   Original_price  Offer  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver          1263.0   32.0
#
#                                                   Final_price  Distance  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver        862.0       9.3
#
#                                                   Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver     4.4            1325.0
#
#                                                     Summary  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Very Good
#
#                                                                           Location  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Kempagowda International Airport
#
#                                                        City
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 9.3

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==9.3)]
# Out:
#                                                   Original_price  Offer  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver          1263.0   32.0
#
#                                                   Final_price  Distance  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver        862.0       9.3
#
#                                                   Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver     4.4            1325.0
#
#                                                     Summary  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Very Good
#
#                                                                           Location  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Kempagowda International Airport
#
#                                                        City
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Kempagowda_International_Airport')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                       Name  Original_price  Offer  \
# 1452  SPOT ON 40114 Jawali Enterprise SPOT             723     32
#
#       Final_price  Distance  Rating  Number_of_Rating    Summary  \
# 1452          493      18.7     4.6               565  Excellent
#
#                               Location       City
# 1452  Kempagowda_International_Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 1636.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==1636)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 106 Airport Road          2654.0   32.0       1810.0       9.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 106 Airport Road     4.5            1636.0  Excellent
#
#                                                         Location       City
# Name
# OYO Townhouse 106 Airport Road  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 9.5

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Distance']==9.5)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 106 Airport Road          2654.0   32.0       1810.0       9.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 106 Airport Road     4.5            1636.0  Excellent
#
#                                                         Location       City
# Name
# OYO Townhouse 106 Airport Road  Kempagowda International Airport  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    6
# 4.6    5
# 4.8    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1281.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1281)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 40115 J P Palace          1878.0   32.0       1281.0      19.0     4.8
#
#                       Number_of_Rating    Summary  \
# Name
# OYO 40115 J P Palace             481.0  Excellent
#
#                                               Location       City
# Name
# OYO 40115 J P Palace  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 481.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==481)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 40115 J P Palace          1878.0   32.0       1281.0      19.0     4.8
#
#                       Number_of_Rating    Summary  \
# Name
# OYO 40115 J P Palace             481.0  Excellent
#
#                                               Location       City
# Name
# OYO 40115 J P Palace  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 19.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==19.0)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 40115 J P Palace          1878.0   32.0       1281.0      19.0     4.8
#
#                       Number_of_Rating    Summary  \
# Name
# OYO 40115 J P Palace             481.0  Excellent
#
#                                               Location       City
# Name
# OYO 40115 J P Palace  Kempagowda International Airport  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 990.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Final_price']==990)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 24130 Surya Comforts          1667.0   41.0        990.0      17.0
#
#                           Rating  Number_of_Rating   Summary  \
# Name
# OYO 24130 Surya Comforts     5.0               2.0  Fabulous
#
#                                                   Location       City
# Name
# OYO 24130 Surya Comforts  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 2.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==2)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 24130 Surya Comforts          1667.0   41.0        990.0      17.0
#
#                           Rating  Number_of_Rating   Summary  \
# Name
# OYO 24130 Surya Comforts     5.0               2.0  Fabulous
#
#                                                   Location       City
# Name
# OYO 24130 Surya Comforts  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 9.5

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Distance']==9.5)]
# Out:
#                      Original_price  Offer  Final_price  Distance  Rating  \
# Name
# Palette - Npg Hotel          2861.0   32.0       1951.0       9.5     5.0
#
#                      Number_of_Rating   Summary  \
# Name
# Palette - Npg Hotel               1.0  Fabulous
#
#                                              Location       City
# Name
# Palette - Npg Hotel  Kempagowda International Airport  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 5.0    3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Final_price'].min()
# Out:
# 990.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Final_price']==990)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 24130 Surya Comforts          1667.0   41.0        990.0      17.0
#
#                           Rating  Number_of_Rating   Summary  \
# Name
# OYO 24130 Surya Comforts     5.0               2.0  Fabulous
#
#                                                   Location       City
# Name
# OYO 24130 Surya Comforts  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Number_of_Rating'].max()
# Out:
# 2.0

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Number_of_Rating']==2)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 24130 Surya Comforts          1667.0   41.0        990.0      17.0
#
#                           Rating  Number_of_Rating   Summary  \
# Name
# OYO 24130 Surya Comforts     5.0               2.0  Fabulous
#
#                                                   Location       City
# Name
# OYO 24130 Surya Comforts  Kempagowda International Airport  Bangalore

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Distance'].min()
# Out:
# 9.5

# %%
b[(b['Location']=='Kempagowda International Airport')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Distance']==9.5)]
# Out:
#                      Original_price  Offer  Final_price  Distance  Rating  \
# Name
# Palette - Npg Hotel          2861.0   32.0       1951.0       9.5     5.0
#
#                      Number_of_Rating   Summary  \
# Name
# Palette - Npg Hotel               1.0  Fabulous
#
#                                              Location       City
# Name
# Palette - Npg Hotel  Kempagowda International Airport  Bangalore

# %% [markdown]
# # Koramangala

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Koramangala']['Summary'].value_counts()
# Out:
# Very Good               84
# Good                    40
# Excellent               32
# Yet to be summarised    14
# Fair                    10
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Koramangala']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.0    19
# 4.4    18
# 4.1    18
# 4.3    16
# 4.2    13
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 903.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==903)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# OYO 23427 Ashrey Comforts          1324.0   32.0        903.0       9.6
#
#                            Rating  Number_of_Rating    Summary     Location  \
# Name
# OYO 23427 Ashrey Comforts     4.4             356.0  Very Good  Koramangala
#
#                                 City
# Name
# OYO 23427 Ashrey Comforts  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       9.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good
#
#                                    Location       City
# Name
# Collection O 30067 Indiranagar  Koramangala  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.6

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.6)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# SPOT ON 60556 Udupi Residency SPOT          2395.0   32.0       1633.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 60556 Udupi Residency SPOT       1.6     4.4             330.0
#
#                                       Summary     Location       City
# Name
# SPOT ON 60556 Udupi Residency SPOT  Very Good  Koramangala  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 710.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Final_price']==710)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 43981 Falcon Tower SPOT          1041.0   32.0        710.0       9.2
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 43981 Falcon Tower SPOT     4.7             459.0  Excellent
#
#                                     Location       City
# Name
# SPOT ON 43981 Falcon Tower SPOT  Koramangala  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2662.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2662)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 30639 Spacious Stay J P Nagar          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 30639 Spacious Stay J P Nagar       5.7     4.5            2662.0
#
#                                      Summary     Location       City
# Name
# OYO 30639 Spacious Stay J P Nagar  Excellent  Koramangala  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.7

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Distance']==0.7)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 24573 Eyrie Comforts          6595.0   32.0       4497.0       0.7
#
#                           Rating  Number_of_Rating    Summary     Location  \
# Name
# OYO 24573 Eyrie Comforts     4.5             103.0  Excellent  Koramangala
#
#                                City
# Name
# OYO 24573 Eyrie Comforts  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    16
# 4.6     9
# 4.7     5
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1005.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1005)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Home 61518 Exotic Stay Bg Road          1474.0   32.0       1005.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Home 61518 Exotic Stay Bg Road       8.7     4.8             110.0
#
#                                       Summary     Location       City
# Name
# OYO Home 61518 Exotic Stay Bg Road  Excellent  Koramangala  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 437.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==437)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       2.0     4.8             437.0
#
#                                     Summary     Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Koramangala  Bangalore

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 2.0

# %%
b[(b['Location']=='Koramangala')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==2.0)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       2.0     4.8             437.0
#
#                                     Summary     Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Koramangala  Bangalore

# %% [markdown]
# # Kr_puram

# %% [markdown]
# ## Very good

# %%
b[b['Location']=='KR Puram']['Summary'].value_counts()
# Out:
# Very Good               31
# Good                    12
# Excellent               11
# Yet to be summarised     3
# Fair                     3
# Name: Summary, dtype: int64

# %%
b[b['Location']=='KR Puram']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    8
# 4.2    8
# 4.3    8
# 4.0    4
# 4.1    3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1215.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1215)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 4848 3 Square Inn          1782.0   32.0       1215.0       9.2     4.4
#
#                        Number_of_Rating    Summary  Location       City
# Name
# OYO 4848 3 Square Inn             360.0  Very Good  KR Puram  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       7.2
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good  KR Puram
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 7.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==7.0)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 255 Indiranagar Double Road          2508.0   32.0       1710.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 255 Indiranagar Double Road       7.0     4.4             114.0
#
#                                              Summary  Location       City
# Name
# OYO Townhouse 255 Indiranagar Double Road  Very Good  KR Puram  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 1331.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Final_price']==1331)]
# Out:
#                                           Original_price  Offer  Final_price  \
# Name
# OYO 2561 Hotel Resida Service Apartments          1952.0   32.0       1331.0
#
#                                           Distance  Rating  Number_of_Rating  \
# Name
# OYO 2561 Hotel Resida Service Apartments       8.5     4.7             477.0
#
#                                             Summary  Location       City
# Name
# OYO 2561 Hotel Resida Service Apartments  Excellent  KR Puram  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 1650.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==1650)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30096 Tin factory          2042.0   32.0       1393.0       3.1
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# Collection O 30096 Tin factory     4.5            1650.0  Excellent  KR Puram
#
#                                      City
# Name
# Collection O 30096 Tin factory  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 3.1

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Distance']==3.1)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30096 Tin factory          2042.0   32.0       1393.0       3.1
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# Collection O 30096 Tin factory     4.5            1650.0  Excellent  KR Puram
#
#                                      City
# Name
# Collection O 30096 Tin factory  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    4
# 4.5    4
# 4.8    2
# 4.7    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1848.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1848)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       8.8
#
#                                Rating  Number_of_Rating    Summary  Location  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent  KR Puram
#
#                                     City
# Name
# Capital O 1324 Silicon Hearth  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 707.0

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==707)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       8.8
#
#                                Rating  Number_of_Rating    Summary  Location  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent  KR Puram
#
#                                     City
# Name
# Capital O 1324 Silicon Hearth  Bangalore

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 5.9

# %%
b[(b['Location']=='KR Puram')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==5.9)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       5.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  KR Puram  Bangalore

# %% [markdown]
# # Majestic

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Majestic']['Summary'].value_counts()
# Out:
# Very Good               83
# Good                    41
# Excellent               33
# Yet to be summarised    14
# Fair                     9
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Majestic']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.1    23
# 4.4    18
# 4.3    15
# 4.2    14
# 4.0    13
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 932.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==932)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 180 Jayanagar Saver          1367.0   32.0        932.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 180 Jayanagar Saver       7.9     4.4            1528.0
#
#                                      Summary  Location       City
# Name
# OYO Townhouse 180 Jayanagar Saver  Very Good  Majestic  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       9.0
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good  Majestic
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 3.9

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==3.9)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 35680 R G Comforts           6595.0   32.0       4497.0       3.9     4.4
#
#                          Number_of_Rating    Summary  Location       City
# Name
# OYO 35680 R G Comforts              445.0  Very Good  Majestic  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 938.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Final_price']==938)]
# Out:
#                      Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 62768 Gm Royals          1376.0   32.0        938.0       8.6     4.5
#
#                      Number_of_Rating    Summary  Location       City
# Name
# OYO 62768 Gm Royals             138.0  Excellent  Majestic  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       6.1
#
#                                Rating  Number_of_Rating    Summary  Location  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent  Majestic
#
#                                     City
# Name
# Capital O 37517 Withinn Hotel  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.8

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Distance']==0.8)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT          1453.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        991.0       0.8
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary  Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  Majestic
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    15
# 4.6    13
# 4.7     3
# 4.8     2
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1010.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1010)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       9.9     4.8             437.0
#
#                                     Summary  Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Majestic  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 437.0

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==437)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# OYO 15016 Hotel City Plaza Saver          1716.0   41.0       1010.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# OYO 15016 Hotel City Plaza Saver       9.9     4.8             437.0
#
#                                     Summary  Location       City
# Name
# OYO 15016 Hotel City Plaza Saver  Excellent  Majestic  Bangalore

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 8.9

# %%
b[(b['Location']=='Majestic')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==8.9)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       8.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Majestic  Bangalore

# %% [markdown]
# # Majestic_City_Railway_Station

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Majestic City Railway Station']['Summary'].value_counts()
# Out:
# Very Good               80
# Good                    38
# Excellent               35
# Yet to be summarised    16
# Fair                    11
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Majestic City Railway Station']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.1    22
# 4.4    16
# 4.3    16
# 4.0    14
# 4.2    12
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 983.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==983)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# SPOT ON 60556 Udupi Residency SPOT          1442.0   32.0        983.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 60556 Udupi Residency SPOT       9.2     4.4             330.0
#
#                                       Summary                       Location  \
# Name
# SPOT ON 60556 Udupi Residency SPOT  Very Good  Majestic City Railway Station
#
#                                          City
# Name
# SPOT ON 60556 Udupi Residency SPOT  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       8.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good
#
#                                                      Location       City
# Name
# Collection O 30067 Indiranagar  Majestic City Railway Station  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 3.7

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==3.7)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 35680 R G Comforts           6595.0   32.0       4497.0       3.7     4.4
#
#                          Number_of_Rating    Summary  \
# Name
# OYO 35680 R G Comforts              445.0  Very Good
#
#                                               Location       City
# Name
# OYO 35680 R G Comforts   Majestic City Railway Station  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       1.6
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent
#
#                                                                       Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Majestic City Railway Station
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       7.5
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent
#
#                                                     Location       City
# Name
# Capital O 37517 Withinn Hotel  Majestic City Railway Station  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 1.4

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Distance']==1.4)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 25036 Suraksha Residency          1460.0   33.0        974.0       1.4
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 25036 Suraksha Residency     4.6             606.0  Excellent
#
#                                                    Location       City
# Name
# OYO 25036 Suraksha Residency  Majestic City Railway Station  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    16
# 4.5    15
# 4.7     3
# 4.8     1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 2664.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==2664)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       8.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                                     Location  \
# Name
# Capital O 41106 37th Crescent Boutique Suites  Majestic City Railway Station
#
#                                                     City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 271.0

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==271)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       8.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                                     Location  \
# Name
# Capital O 41106 37th Crescent Boutique Suites  Majestic City Railway Station
#
#                                                     City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Bangalore

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 8.9

# %%
b[(b['Location']=='Majestic City Railway Station')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==8.9)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       8.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                                     Location  \
# Name
# Capital O 41106 37th Crescent Boutique Suites  Majestic City Railway Station
#
#                                                     City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Bangalore

# %% [markdown]
# # Marathahalli

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Marathahalli']['Summary'].value_counts()
# Out:
# Very Good               33
# Excellent               12
# Good                    11
# Fair                     3
# Yet to be summarised     1
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Marathahalli']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.2    10
# 4.3     7
# 4.4     6
# 4.1     6
# 4.0     4
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1280.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1280)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# Collection O 40090 Vittala Comfort          1877.0   32.0       1280.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# Collection O 40090 Vittala Comfort       8.4     4.4            1815.0
#
#                                       Summary      Location       City
# Name
# Collection O 40090 Vittala Comfort  Very Good  Marathahalli  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1815.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1815)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# Collection O 40090 Vittala Comfort          1877.0   32.0       1280.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# Collection O 40090 Vittala Comfort       8.4     4.4            1815.0
#
#                                       Summary      Location       City
# Name
# Collection O 40090 Vittala Comfort  Very Good  Marathahalli  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 3.4

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==3.4)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 15744 Northern Suites          2147.0   32.0       1464.0       3.4
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# Capital O 15744 Northern Suites     4.4            1089.0  Very Good
#
#                                      Location       City
# Name
# Capital O 15744 Northern Suites  Marathahalli  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 1393.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Final_price']==1393)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30096 Tin factory          2042.0   32.0       1393.0       5.2
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Collection O 30096 Tin factory     4.5            1650.0  Excellent
#
#                                     Location       City
# Name
# Collection O 30096 Tin factory  Marathahalli  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2481.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2481)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 25030 D'brooks          2956.0   32.0       2016.0       3.4
#
#                           Rating  Number_of_Rating    Summary      Location  \
# Name
# Capital O 25030 D'brooks     4.5            2481.0  Excellent  Marathahalli
#
#                                City
# Name
# Capital O 25030 D'brooks  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 3.1

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Distance']==3.1)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       3.1
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                    Location       City
# Name
# Capital O 1324 Silicon Hearth  Marathahalli  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    6
# 4.6    3
# 4.8    2
# 4.7    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1848.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1848)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       3.1
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                    Location       City
# Name
# Capital O 1324 Silicon Hearth  Marathahalli  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 707.0

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==707)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       3.1
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                    Location       City
# Name
# Capital O 1324 Silicon Hearth  Marathahalli  Bangalore

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 3.1

# %%
b[(b['Location']=='Marathahalli')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==3.1)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       3.1
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                    Location       City
# Name
# Capital O 1324 Silicon Hearth  Marathahalli  Bangalore

# %% [markdown]
# # Mg_road

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='MG Road']['Summary'].value_counts()
# Out:
# Very Good               112
# Good                     56
# Excellent                44
# Yet to be summarised     19
# Fair                      9
# Name: Summary, dtype: int64

# %%
b[b['Location']=='MG Road']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    25
# 4.0    25
# 4.1    24
# 4.4    20
# 4.2    18
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1010.0

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1010)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 11916 Varcity Plaza              2223.0   55.0       1010.0       8.2
# OYO Townhouse 180 Jayanagar          1481.0   32.0       1010.0       6.4
#
#                              Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 11916 Varcity Plaza         4.4             719.0  Very Good  MG Road
# OYO Townhouse 180 Jayanagar     4.4            1528.0  Very Good  MG Road
#
#                                   City
# Name
# OYO 11916 Varcity Plaza      Bangalore
# OYO Townhouse 180 Jayanagar  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       3.2
#
#                                 Rating  Number_of_Rating    Summary Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good  MG Road
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.3

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.3)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 9925 The Ocea International          2268.0   35.0       1471.0       1.3
#
#                                  Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 9925 The Ocea International     4.4             472.0  Very Good  MG Road
#
#                                       City
# Name
# OYO 9925 The Ocea International  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       6.1
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary Location       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  MG Road  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       8.4
#
#                                Rating  Number_of_Rating    Summary Location  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent  MG Road
#
#                                     City
# Name
# Capital O 37517 Withinn Hotel  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.7

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')&(b['Distance']==0.7)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO 27280 Hotel Maya International          6573.0   32.0       4482.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO 27280 Hotel Maya International       0.7     4.6             596.0
#
#                                       Summary Location       City
# Name
# OYO 27280 Hotel Maya International  Excellent  MG Road  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    19
# 4.6    16
# 4.7     5
# 4.8     4
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Excellent')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# nan

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1010)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 11916 Varcity Plaza              2223.0   55.0       1010.0       8.2
# OYO Townhouse 180 Jayanagar          1481.0   32.0       1010.0       6.4
#
#                              Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 11916 Varcity Plaza         4.4             719.0  Very Good  MG Road
# OYO Townhouse 180 Jayanagar     4.4            1528.0  Very Good  MG Road
#
#                                   City
# Name
# OYO 11916 Varcity Plaza      Bangalore
# OYO Townhouse 180 Jayanagar  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1996.0

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1996)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Collection O 30067 Indiranagar          3132.0   32.0       2136.0       3.2
#
#                                 Rating  Number_of_Rating    Summary Location  \
# Name
# Collection O 30067 Indiranagar     4.4            1996.0  Very Good  MG Road
#
#                                      City
# Name
# Collection O 30067 Indiranagar  Bangalore

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.3

# %%
b[(b['Location']=='MG Road')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.3)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 9925 The Ocea International          2268.0   35.0       1471.0       1.3
#
#                                  Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 9925 The Ocea International     4.4             472.0  Very Good  MG Road
#
#                                       City
# Name
# OYO 9925 The Ocea International  Bangalore

# %% [markdown]
# # Rajaji_nagar

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Rajaji Nagar']['Summary'].value_counts()
# Out:
# Very Good               57
# Good                    36
# Excellent               25
# Yet to be summarised    13
# Fair                     8
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Rajaji Nagar']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    15
# 4.1    14
# 4.2    11
# 4.3     9
# 4.0     8
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 655.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==655)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT           961.0   32.0        655.0       5.1
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT     4.4             429.0  Very Good
#
#                                   Location       City
# Name
# SPOT ON 47215 Jp Hotel  SPOT  Rajaji Nagar  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1215.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1215)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# Capital O 23481 Rmv Savera Hotels          2647.0   32.0       1805.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# Capital O 23481 Rmv Savera Hotels       6.4     4.4            1215.0
#
#                                      Summary      Location       City
# Name
# Capital O 23481 Rmv Savera Hotels  Very Good  Rajaji Nagar  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 3.6

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==3.6)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# OYO 14424 Saarang Forever          1906.0   48.0       1000.0       3.6
#
#                            Rating  Number_of_Rating    Summary      Location  \
# Name
# OYO 14424 Saarang Forever     4.4             377.0  Very Good  Rajaji Nagar
#
#                                 City
# Name
# OYO 14424 Saarang Forever  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       4.1
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary      Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  Rajaji Nagar
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       6.5
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent
#
#                                    Location       City
# Name
# Capital O 37517 Withinn Hotel  Rajaji Nagar  Bangalore

# %%
b[(b['Location']=='Rajaji Nagarb['Summary']=='Excellent')]['Distance'].min()
# Out:
#   File "<ipython-input-464-459e1ed8b877>", line 1
#     b[(b['Location']=='Rajaji Nagarb['Summary']=='Excellent')]['Distance'].min()
#                                             ^
# SyntaxError: invalid syntax

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Distance']==0.1)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13594 Mathrushree Residency          6584.0   32.0       4489.0       0.1
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 13594 Mathrushree Residency     4.5              50.0  Excellent
#
#                                      Location       City
# Name
# OYO 13594 Mathrushree Residency  Rajaji Nagar  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    12
# 4.5    10
# 4.7     2
# 4.8     1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 2583.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==2583)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       8.9     4.8            1763.0
#
#                                            Summary      Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent  Rajaji Nagar  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 1763.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==1763)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       8.9     4.8            1763.0
#
#                                            Summary      Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent  Rajaji Nagar  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 8.9

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==8.9)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore          5654.0   54.0       2583.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 025 Garuda Mall Bangalore       8.9     4.8            1763.0
#
#                                            Summary      Location       City
# Name
# OYO Townhouse 025 Garuda Mall Bangalore  Excellent  Rajaji Nagar  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 4489.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Final_price']==4489)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 109.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==109)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 8.2

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Distance']==8.2)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 4.9    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)]['Final_price'].min()
# Out:
# 4489.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)&(b['Final_price']==4489)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)]['Number_of_Rating'].max()
# Out:
# 109.0

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)&(b['Number_of_Rating']==109)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)]['Distance'].min()
# Out:
# 8.2

# %%
b[(b['Location']=='Rajaji Nagar')&(b['Summary']=='Fabulous')&(b['Rating']==4.9)&(b['Distance']==8.2)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       8.2
#
#                             Rating  Number_of_Rating   Summary      Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Rajaji Nagar
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %% [markdown]
# # Whitefield

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Whitefield']['Summary'].value_counts()
# Out:
# Very Good    9
# Good         6
# Excellent    4
# Fair         1
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Whitefield']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.2    3
# 4.4    2
# 4.1    2
# 4.3    1
# 4.0    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 1464.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==1464)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 15744 Northern Suites          2147.0   32.0       1464.0       6.1
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# Capital O 15744 Northern Suites     4.4            1089.0  Very Good
#
#                                    Location       City
# Name
# Capital O 15744 Northern Suites  Whitefield  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1348.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1348)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 581 Serene Grove          2500.0   32.0       1705.0       7.2
#
#                             Rating  Number_of_Rating    Summary    Location  \
# Name
# Capital O 581 Serene Grove     4.4            1348.0  Very Good  Whitefield
#
#                                  City
# Name
# Capital O 581 Serene Grove  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 6.1

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==6.1)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 15744 Northern Suites          2147.0   32.0       1464.0       6.1
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# Capital O 15744 Northern Suites     4.4            1089.0  Very Good
#
#                                    Location       City
# Name
# Capital O 15744 Northern Suites  Whitefield  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 1594.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Final_price']==1594)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# Capital O 22490 Hotel Paradise Inn          2338.0   32.0       1594.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# Capital O 22490 Hotel Paradise Inn       7.2     4.6            1289.0
#
#                                       Summary    Location       City
# Name
# Capital O 22490 Hotel Paradise Inn  Excellent  Whitefield  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2481.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2481)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 25030 D'brooks          2956.0   32.0       2016.0       6.1
#
#                           Rating  Number_of_Rating    Summary    Location  \
# Name
# Capital O 25030 D'brooks     4.5            2481.0  Excellent  Whitefield
#
#                                City
# Name
# Capital O 25030 D'brooks  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 6.1

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Distance']==6.1)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 25030 D'brooks          2956.0   32.0       2016.0       6.1
#
#                           Rating  Number_of_Rating    Summary    Location  \
# Name
# Capital O 25030 D'brooks     4.5            2481.0  Excellent  Whitefield
#
#                                City
# Name
# Capital O 25030 D'brooks  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    2
# 4.8    1
# 4.5    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 1848.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==1848)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       7.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                  Location       City
# Name
# Capital O 1324 Silicon Hearth  Whitefield  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 707.0

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==707)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       7.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                  Location       City
# Name
# Capital O 1324 Silicon Hearth  Whitefield  Bangalore

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 7.7

# %%
b[(b['Location']=='Whitefield')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==7.7)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 1324 Silicon Hearth          2710.0   32.0       1848.0       7.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 1324 Silicon Hearth     4.8             707.0  Excellent
#
#                                  Location       City
# Name
# Capital O 1324 Silicon Hearth  Whitefield  Bangalore

# %% [markdown]
# # Yelahanka

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Yelahanka']['Summary'].value_counts()
# Out:
# Very Good               39
# Good                    16
# Excellent                8
# Fair                     7
# Yet to be summarised     6
# Fabulous                 4
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Yelahanka']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    9
# 4.1    9
# 4.2    8
# 4.3    7
# 4.0    6
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 655.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==655)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT           961.0   32.0        655.0       8.9
#
#                               Rating  Number_of_Rating    Summary   Location  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT     4.4             429.0  Very Good  Yelahanka
#
#                                    City
# Name
# SPOT ON 47215 Jp Hotel  SPOT  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1325.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1325)]
# Out:
#                                                   Original_price  Offer  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver          1263.0   32.0
#
#                                                   Final_price  Distance  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver        862.0       9.5
#
#                                                   Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver     4.4            1325.0
#
#                                                     Summary   Location  \
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Very Good  Yelahanka
#
#                                                        City
# Name
# SilverKey Executive Stays 44663 R Stay Inn Saver  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 3.2

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==3.2)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# OYO 15482 Delite Suites Saver          1481.0   32.0       1010.0       3.2
#
#                                Rating  Number_of_Rating    Summary   Location  \
# Name
# OYO 15482 Delite Suites Saver     4.4             277.0  Very Good  Yelahanka
#
#                                     City
# Name
# OYO 15482 Delite Suites Saver  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Final_price']==778)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 48879 GN Comforts          1140.0   32.0        778.0       9.5     4.6
#
#                        Number_of_Rating    Summary   Location       City
# Name
# OYO 48879 GN Comforts              37.0  Excellent  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       7.5
#
#                                Rating  Number_of_Rating    Summary   Location  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent  Yelahanka
#
#                                     City
# Name
# Capital O 37517 Withinn Hotel  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 6.5

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Distance']==6.5)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 29402 Udupi Shubha Sagar          1481.0   32.0       1010.0       6.5
#
#                               Rating  Number_of_Rating    Summary   Location  \
# Name
# OYO 29402 Udupi Shubha Sagar     4.6              58.0  Excellent  Yelahanka
#
#                                    City
# Name
# OYO 29402 Udupi Shubha Sagar  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    5
# 4.7    1
# 4.8    1
# 4.5    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Final_price'].min()
# Out:
# 2664.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Final_price']==2664)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       9.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                 Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 271.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Number_of_Rating']==271)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       9.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                 Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)]['Distance'].min()
# Out:
# 9.9

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Excellent')&(b['Rating']==4.8)&(b['Distance']==9.9)]
# Out:
#                                                Original_price  Offer  \
# Name
# Capital O 41106 37th Crescent Boutique Suites          3907.0   32.0
#
#                                                Final_price  Distance  Rating  \
# Name
# Capital O 41106 37th Crescent Boutique Suites       2664.0       9.9     4.8
#
#                                                Number_of_Rating    Summary  \
# Name
# Capital O 41106 37th Crescent Boutique Suites             271.0  Excellent
#
#                                                 Location       City
# Name
# Capital O 41106 37th Crescent Boutique Suites  Yelahanka  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.7     5.0
#
#                        Number_of_Rating   Summary   Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 109.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==109)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13043 Pavithra Regency          6584.0   32.0       4489.0       9.1
#
#                             Rating  Number_of_Rating   Summary   Location  \
# Name
# OYO 13043 Pavithra Regency     4.9             109.0  Fabulous  Yelahanka
#
#                                  City
# Name
# OYO 13043 Pavithra Regency  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 1.8

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Distance']==1.8)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 29020 Vm Comfort          2313.0   32.0       1577.0       1.8     5.0
#
#                       Number_of_Rating   Summary   Location       City
# Name
# OYO 29020 Vm Comfort               1.0  Fabulous  Yelahanka  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 5.0    3
# 4.9    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.7     5.0
#
#                        Number_of_Rating   Summary   Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Number_of_Rating'].max()
# Out:
# 1.0

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Number_of_Rating']==1)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 29020 Vm Comfort           2313.0   32.0       1577.0       1.8     5.0
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       6.7     5.0
# Palette - Npg Hotel            2861.0   32.0       1951.0       9.2     5.0
#
#                        Number_of_Rating   Summary   Location       City
# Name
# OYO 29020 Vm Comfort                1.0  Fabulous  Yelahanka  Bangalore
# OYO 19285 Uv Comforts               1.0  Fabulous  Yelahanka  Bangalore
# Palette - Npg Hotel                 1.0  Fabulous  Yelahanka  Bangalore

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Distance'].min()
# Out:
# 1.8

# %%
b[(b['Location']=='Yelahanka')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Distance']==1.8)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 29020 Vm Comfort          2313.0   32.0       1577.0       1.8     5.0
#
#                       Number_of_Rating   Summary   Location       City
# Name
# OYO 29020 Vm Comfort               1.0  Fabulous  Yelahanka  Bangalore

# %% [markdown]
# # Yeshwanthpur

# %% [markdown]
# ## Very Good

# %%
b[b['Location']=='Yeshwanthpur']['Summary'].value_counts()
# Out:
# Very Good               46
# Excellent               19
# Good                    19
# Yet to be summarised     9
# Fair                     6
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
b[b['Location']=='Yeshwanthpur']['Summary'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    13
# 4.1    11
# 4.0     9
# 4.2     8
# 4.3     5
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Final_price'].min()
# Out:
# 655.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Final_price']==655)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT           961.0   32.0        655.0       4.3
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# SPOT ON 47215 Jp Hotel  SPOT     4.4             429.0  Very Good
#
#                                   Location       City
# Name
# SPOT ON 47215 Jp Hotel  SPOT  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1215.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Number_of_Rating']==1215)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# Capital O 23481 Rmv Savera Hotels          2647.0   32.0       1805.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# Capital O 23481 Rmv Savera Hotels       5.6     4.4            1215.0
#
#                                      Summary      Location       City
# Name
# Capital O 23481 Rmv Savera Hotels  Very Good  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)]['Distance'].min()
# Out:
# 1.7

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Very Good')&(b['Rating']==4.4)&(b['Distance']==1.7)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# OYO 14424 Saarang Forever          1906.0   49.0        975.0       1.7
#
#                            Rating  Number_of_Rating    Summary      Location  \
# Name
# OYO 14424 Saarang Forever     4.4             377.0  Very Good  Yeshwanthpur
#
#                                 City
# Name
# OYO 14424 Saarang Forever  Bangalore

# %% [markdown]
# ## Excellent

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 493.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Final_price']==493)]
# Out:
#                                                  Original_price  Offer  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT           723.0   32.0
#
#                                                  Final_price  Distance  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT        493.0       9.5
#
#                                                  Rating  Number_of_Rating  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT     4.5            2187.0
#
#                                                    Summary      Location  \
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Excellent  Yeshwanthpur
#
#                                                       City
# Name
# SPOT ON 41554 Hotel Sri Thirumala Paradise SPOT  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 2840.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Number_of_Rating']==2840)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37517 Withinn Hotel          2140.0   32.0       1459.0       5.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 37517 Withinn Hotel     4.6            2840.0  Excellent
#
#                                    Location       City
# Name
# Capital O 37517 Withinn Hotel  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')]['Distance'].min()
# Out:
# 2.9

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Distance']==2.9)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 30686 G K Residency          1394.0   32.0        951.0       2.9     4.7
#
#                          Number_of_Rating    Summary      Location       City
# Name
# OYO 30686 G K Residency             283.0  Excellent  Yeshwanthpur  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    10
# 4.5     6
# 4.7     3
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Final_price'].min()
# Out:
# 951.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Final_price']==951)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 30686 G K Residency          1394.0   32.0        951.0       2.9     4.7
#
#                          Number_of_Rating    Summary      Location       City
# Name
# OYO 30686 G K Residency             283.0  Excellent  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Number_of_Rating'].max()
# Out:
# 1838.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Number_of_Rating']==1838)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 10534 Hotel Kanishka          1906.0   32.0       1294.0       9.9
#
#                           Rating  Number_of_Rating    Summary      Location  \
# Name
# OYO 10534 Hotel Kanishka     4.7            1838.0  Excellent  Yeshwanthpur
#
#                                City
# Name
# OYO 10534 Hotel Kanishka  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)]['Distance'].min()
# Out:
# 2.9

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Excellent')&(b['Rating']==4.7)&(b['Distance']==2.9)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 30686 G K Residency          1394.0   32.0        951.0       2.9     4.7
#
#                          Number_of_Rating    Summary      Location       City
# Name
# OYO 30686 G K Residency             283.0  Excellent  Yeshwanthpur  Bangalore

# %% [markdown]
# ## Fabulous

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')]['Number_of_Rating'].max()
# Out:
# 1.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Number_of_Rating']==1)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')]['Distance'].min()
# Out:
# 8.4

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Distance']==8.4)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore

# %% [markdown]
# ## With Rating

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 5.0    1
# Name: Rating, dtype: int64

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')]['Rating'].value_counts().plot.bar()

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Final_price'].min()
# Out:
# 1290.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Final_price']==1290)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Number_of_Rating'].max()
# Out:
# 1.0

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Number_of_Rating']==1)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)]['Distance'].min()
# Out:
# 8.4

# %%
b[(b['Location']=='Yeshwanthpur')&(b['Summary']=='Fabulous')&(b['Rating']==5.0)&(b['Distance']==8.4)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 19285 Uv Comforts          1892.0   32.0       1290.0       8.4     5.0
#
#                        Number_of_Rating   Summary      Location       City
# Name
# OYO 19285 Uv Comforts               1.0  Fabulous  Yeshwanthpur  Bangalore
