# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cleaned_Data.csv',index_col=0)

# %%
df
# Out:
#                                                    Original_price  Offer  \
# Name
# OYO 22085 Raj Banjara White House                          2459.0   32.0
# Collection O 42514 Venkat Nagar                            3158.0   32.0
# Capital O 44354 Jubilee Banjara Suites                     1778.0   32.0
# OYO 35487 Hotel Meena Grand                                2090.0   32.0
# OYO 16018 Rainbow Saphire                                  2607.0   32.0
# Collection O 46198 New Sree Krishna                        3964.0   32.0
# OYO 14224 Happy Guest house                                2373.0   32.0
# OYO 62547 Dream Connect Stays                              1941.0   32.0
# OYO 11376 Golden Park                                      2205.0   45.0
# OYO 11316 Athithi Inn                                      2178.0   38.0
# OYO 10272 Hotel Ruma                                       1777.0   32.0
# OYO 18725 Sr Grand                                         1910.0   32.0
# ...

# %% [markdown]
# # Hyderabad

# %%
h=df[df['City']=='Hyderabad']

# %%
h['Location'].unique()
# Out:
# array(['Banjara Hills', 'Jubilee Hills', 'Kondapur', 'Hitech City',
#        'Begumpet', 'Mehdipatnam', 'Kachiguda Railway Station',
#        'Secunderabad Railway Station', 'LB Nagar', 'Kukatpally', 'Uppal',
#        'Gachibowli', 'Ameerpet', 'Rajiv Gandhi International Airport',
#        'Lakdikapool', 'Shamshabad', 'Himayathnagar', 'Madhapur',
#        'Miyapur', 'Nampally'], dtype=object)

# %% [markdown]
# ## Banjara Hills

# %%
h[h['Location']=='Banjara Hills']['Summary'].value_counts()
# Out:
# Very Good               80
# Good                    37
# Excellent               34
# Fair                    18
# Yet to be summarised    10
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Banjara Hills']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ### Fabulous

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 4.9    1
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       7.8     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                      Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Banjara Hills  Hyderabad

# %% [markdown]
# ### Excellent

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    15
# 4.6    10
# 4.7     5
# 4.8     4
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')&(h['Final_price']==778.00)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       6.6
#
#                           Rating  Number_of_Rating    Summary       Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  Banjara Hills
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       5.1
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                      Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Banjara Hills  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 1.8

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent')&(h['Distance']==1.8)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 14224 Happy Guest house          2373.0   32.0       1618.0       1.8
#
#                              Rating  Number_of_Rating    Summary  \
# Name
# OYO 14224 Happy Guest house     4.6             448.0  Excellent
#
#                                   Location       City
# Name
# OYO 14224 Happy Guest house  Banjara Hills  Hyderabad

# %% [markdown]
# ### RATING = 4.8

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1431.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       4.1     4.8             644.0
#
#                                              Summary       Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Banjara Hills  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3290.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       7.9     4.8            3290.0
#
#                                     Summary       Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Banjara Hills  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 2.9

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==2.9)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       2.9     4.8            2628.0
#
#                                            Summary       Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Banjara Hills  Hyderabad

# %% [markdown]
# ### 'Very Good'

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    25
# 4.3    18
# 4.2    13
# 4.1    12
# 4.0    12
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       6.6     4.4             515.0
#
#                                      Summary       Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Banjara Hills  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       6.1
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                      Location       City
# Name
# OYO Townhouse 064 Secunderabad  Banjara Hills  Hyderabad

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.1

# %%
h[(h['Location']=='Banjara Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.1)]
# Out:
#                                         Original_price  Offer  Final_price  \
# Name
# Capital O 44354 Jubilee Banjara Suites          1778.0   32.0       1213.0
#
#                                         Distance  Rating  Number_of_Rating  \
# Name
# Capital O 44354 Jubilee Banjara Suites       1.1     4.4            1258.0
#
#                                           Summary       Location       City
# Name
# Capital O 44354 Jubilee Banjara Suites  Very Good  Banjara Hills  Hyderabad

# %% [markdown]
# ### OBSERVATION
#
# 			FABULOUS:
# 				OYO 14501 Hotel Hill View Guest House Begumpet
#
# 			EXCELLENT:
# 				LEAST FINAL PRICE:
# 					OYO 49253 Raja Residency
# 				HIGHEST NUMBER OF RATING:
# 					OYO Flagship 15391 Mehdipatnam
# 				LEAST DISTANCE:
# 					OYO 14224 Happy Guest house
#
#
# 				RATING = 4.8:
# 					LEAST FINAL PRICE:
# 						Capital O 46832 Gaayatri Residency Deluxe
# 					HIGHEST NUMBER OF RATING:
# 						Capital O 9003 Deccan Inn Deluxe
# 					LEAST DISTANCE:
# 						Capital O 45597 Hotel Riya Grand Deluxe
#
# 			VERY GOOD:
# 				LEAST FINAL PRICE:
# 					OYO 44275 Three Castles Executive
# 				HIGHEST NUMBER OF RATING:
# 					OYO Townhouse 064 Secunderabad
# 				LEAST DISTANCE:
# 					Capital O 44354 Jubilee Banjara Suites

# %% [markdown]
# ## Jubilee Hills

# %%
h[h['Location']=='Jubilee Hills']['Summary'].value_counts()
# Out:
# Very Good               86
# Good                    37
# Excellent               33
# Yet to be summarised    12
# Fair                    12
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Jubilee Hills']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ### Excellent

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    18
# 4.6     8
# 4.8     4
# 4.7     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       8.3     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==3834.0)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          3235.0   32.0       2206.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       9.9     4.5            3834.0
#
#                                         Summary       Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 2.4

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent')&(h['Distance']==2.4)]
# Out:
#                            Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 6422 Luxor Park          2737.0   32.0       1867.0       2.4
#
#                            Rating  Number_of_Rating    Summary       Location  \
# Name
# Capital O 6422 Luxor Park     4.5            1914.0  Excellent  Jubilee Hills
#
#                                 City
# Name
# Capital O 6422 Luxor Park  Hyderabad

# %% [markdown]
# ### Rating = 4.8

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       8.3     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3630.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3630.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       8.3     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 3.3

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==3.3)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       3.3     4.8            3290.0
#
#                                     Summary       Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Jubilee Hills  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    26
# 4.0    20
# 4.3    18
# 4.2    12
# 4.1    10
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       8.5     4.4             515.0
#
#                                      Summary       Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       9.0
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                      Location       City
# Name
# OYO Townhouse 064 Secunderabad  Jubilee Hills  Hyderabad

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 0.1

# %%
h[(h['Location']=='Jubilee Hills') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==0.1)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 47332 Hotel Dolphin          1481.0   32.0       1010.0       0.1     4.4
#
#                          Number_of_Rating    Summary       Location       City
# Name
# OYO 47332 Hotel Dolphin             279.0  Very Good  Jubilee Hills  Hyderabad

# %% [markdown]
# ### OBSERVATION

# %% [markdown]
#                EXCELLENT:
#                     LEAST FINAL PRICE
#                         SPOT ON 37214 Classic Lodge SPOT
#                     HIGHEST NUMBER OF RATING:
#                         OYO 41729 Elite Stay JNTU Kukatpally
#                     LEAST DISTANCE:
#                         Capital O 6422 Luxor Park
#
#                     RATING = 4.8
#                         LEAST FINAL PRICE
#                             SPOT ON 37214 Classic Lodge SPOT
#                         HIGHEST NUMBER OF RATING:
#                             SPOT ON 37214 Classic Lodge SPOT
#                         LEAST DISTANCE:
#                             Capital O 9003 Deccan Inn Deluxe
#
#                 VERY GOOD:
#                     LEAST FINAL PRICE
#                         OYO 44275 Three Castles Executive
#                     HIGHEST NUMBER OF RATING:
#                         OYO Townhouse 064 Secunderabad
#                     LEAST DISTANCE:
#                         OYO 47332 Hotel Dolphin

# %% [markdown]
# ## Kondapur

# %%
h[h['Location']=='Kondapur']['Summary'].value_counts()
# Out:
# Very Good               57
# Good                    24
# Excellent               23
# Fair                     9
# Yet to be summarised     7
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Kondapur']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    14
# 4.6     4
# 4.7     3
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') &(h['Final_price']==763.00)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       4.9
#
#                              Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Kondapur
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') &(h['Number_of_Rating']==3834.00)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       5.2     4.5            3834.0
#
#                                         Summary  Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Kondapur  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.3

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent')&(h['Distance']==0.3)]
# Out:
#                      Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 44149 Globextra          1810.0   32.0       1234.0       0.3     4.5
#
#                      Number_of_Rating    Summary  Location       City
# Name
# OYO 44149 Globextra             575.0  Excellent  Kondapur  Hyderabad

# %% [markdown]
# ### Rating = 4.8

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1930.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1930.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       6.0     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Kondapur  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3290.0)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       6.0     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Kondapur  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 6.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==6.0)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       6.0     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Kondapur  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    15
# 4.0    14
# 4.2    13
# 4.3    11
# 4.1     4
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 964.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==964.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1479.0   35.0        964.0       2.6
#
#                               Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Kondapur
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2028.0

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==2028.0)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe          3446.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe       2350.0       2.3     4.4
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe            2028.0  Very Good
#
#                                               Location       City
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe  Kondapur  Hyderabad

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.3

# %%
h[(h['Location']=='Kondapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.3)]
# Out:
#                                           Original_price  Offer  Final_price  \
# Name
# Capital O 61839 Scrummys Kondapur Deluxe          2112.0   32.0       1440.0
#
#                                           Distance  Rating  Number_of_Rating  \
# Name
# Capital O 61839 Scrummys Kondapur Deluxe       1.3     4.4              86.0
#
#                                             Summary  Location       City
# Name
# Capital O 61839 Scrummys Kondapur Deluxe  Very Good  Kondapur  Hyderabad

# %% [markdown]
# ## Hitech City

# %%
h[h['Location']=='Hitech City']['Summary'].value_counts()
# Out:
# Very Good               69
# Good                    28
# Excellent               26
# Fair                    11
# Yet to be summarised     6
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Hitech City']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    15
# 4.6     6
# 4.7     3
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')&(h['Final_price']==763)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       8.7
#
#                              Rating  Number_of_Rating    Summary     Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Hitech City
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==3834)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       5.7     4.5            3834.0
#
#                                         Summary     Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.3

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent')&(h['Distance']==0.3)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Collection O 44177 Patrika Nagar          3118.0   32.0       2126.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Collection O 44177 Patrika Nagar       0.3     4.5            1571.0
#
#                                     Summary     Location       City
# Name
# Collection O 44177 Patrika Nagar  Excellent  Hitech City  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 9003 Deccan Inn Deluxe                      2830.0   32.0
# OYO 14503 Hotel Hill View Guest House Deluxe          6410.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe                   1930.0       3.6     4.8
# OYO 14503 Hotel Hill View Guest House Deluxe       4371.0       7.9     4.8
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 9003 Deccan Inn Deluxe                        3290.0  Excellent
# OYO 14503 Hotel Hill View Guest House Deluxe             166.0  Excellent
#
#                                                  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe              Hitech City  Hyderabad
# OYO 14503 Hotel Hill View Guest House Deluxe  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1930.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1930)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       3.6     4.8            3290.0
#
#                                     Summary     Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3290)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       3.6     4.8            3290.0
#
#                                     Summary     Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 3.6

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==3.6)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       3.6     4.8            3290.0
#
#                                     Summary     Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Hitech City  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    19
# 4.3    17
# 4.0    16
# 4.2    13
# 4.1     4
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 964.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==964.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1479.0   35.0        964.0       4.7
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good
#
#                                  Location       City
# Name
# OYO 22425 Hotel Honey Cruise  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2104.0

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==2104.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37516 Apple Tree Inn          3344.0   32.0       2280.0       9.1
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Capital O 37516 Apple Tree Inn     4.4            2104.0  Very Good
#
#                                    Location       City
# Name
# Capital O 37516 Apple Tree Inn  Hitech City  Hyderabad

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.4

# %%
h[(h['Location']=='Hitech City') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.4)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO 62254 Premium Stay Hitech City          2134.0   32.0       1455.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO 62254 Premium Stay Hitech City       1.4     4.4            1289.0
#
#                                       Summary     Location       City
# Name
# OYO 62254 Premium Stay Hitech City  Very Good  Hitech City  Hyderabad

# %% [markdown]
# ## Begumpet

# %%
h[h['Location']=='Begumpet']['Summary'].value_counts()
# Out:
# Very Good               67
# Good                    33
# Excellent               31
# Fair                    16
# Yet to be summarised    12
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Begumpet']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Fabulous

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Fabulous')]['Rating'].value_counts()
# Out:
# 4.9    1
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       3.1     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                 Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Begumpet  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    13
# 4.6     9
# 4.7     7
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Begumpet')&(h['Summary']=='Excellent')&(h['Final_price']==778.0)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       4.8
#
#                           Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  Begumpet
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Begumpet')&(h['Summary']=='Excellent')&(h['Number_of_Rating']==5342.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       8.6
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent  Begumpet
#
#                                      City
# Name
# OYO Flagship 15391 Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 1.8

# %%
h[(h['Location']=='Begumpet')&(h['Summary']=='Excellent')&(h['Distance']==1.8)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 18454 Hallmark Inn Begumpet          2390.0   58.0       1010.0       1.8
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 18454 Hallmark Inn Begumpet     4.7             239.0  Excellent
#
#                                  Location       City
# Name
# OYO 18454 Hallmark Inn Begumpet  Begumpet  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe               3363.0   32.0
# OYO 14503 Hotel Hill View Guest House Deluxe          6410.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe            2293.0       4.7     4.8
# OYO 14503 Hotel Hill View Guest House Deluxe       4371.0       9.8     4.8
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe                 2628.0  Excellent
# OYO 14503 Hotel Hill View Guest House Deluxe             166.0  Excellent
#
#                                               Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       Begumpet  Hyderabad
# OYO 14503 Hotel Hill View Guest House Deluxe  Begumpet  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 2293.0

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==2293.00)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       4.7     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Begumpet  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 2628.0

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==2628.00)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       4.7     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Begumpet  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 4.7

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==4.7)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       4.7     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Begumpet  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    18
# 4.3    14
# 4.2    13
# 4.1    12
# 4.0    10
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       6.0     4.4             515.0
#
#                                      Summary  Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Begumpet  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       2.4
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good  Begumpet
#
#                                      City
# Name
# OYO Townhouse 064 Secunderabad  Hyderabad

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 2.4

# %%
h[(h['Location']=='Begumpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==2.4)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       2.4
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good  Begumpet
#
#                                      City
# Name
# OYO Townhouse 064 Secunderabad  Hyderabad

# %% [markdown]
# ## Mehdipatnam

# %%
h[h['Location']=='Mehdipatnam']['Summary'].value_counts()
# Out:
# Very Good               59
# Good                    32
# Excellent               29
# Yet to be summarised    10
# Fair                    10
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Mehdipatnam']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    12
# 4.6     9
# 4.7     4
# 4.8     4
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Final_price']==563)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.2     4.8            3630.0
#
#                                     Summary     Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==5342)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       0.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                    Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.5

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Distance']==0.5)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       0.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                    Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Mehdipatnam  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.2     4.8            3630.0
#
#                                     Summary     Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3630.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3630.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.2     4.8            3630.0
#
#                                     Summary     Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 2.9

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==2.9)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       2.9     4.8            2628.0
#
#                                            Summary     Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Mehdipatnam  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    18
# 4.3    15
# 4.2    10
# 4.1    10
# 4.0     6
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       3.4     4.4             515.0
#
#                                      Summary     Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       7.6
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                    Location       City
# Name
# OYO Townhouse 064 Secunderabad  Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 3.4

# %%
h[(h['Location']=='Mehdipatnam') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==3.4)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       3.4     4.4             515.0
#
#                                      Summary     Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Mehdipatnam  Hyderabad

# %% [markdown]
# ## Kachiguda Railway Station

# %%
h[h['Location']=='Kachiguda Railway Station']['Summary'].value_counts()
# Out:
# Very Good               42
# Good                    24
# Excellent               20
# Fair                     9
# Yet to be summarised     5
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Kachiguda Railway Station']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    7
# 4.5    7
# 4.7    3
# 4.8    3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')& (h['Final_price']==563.0)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.5     4.8            3630.0
#
#                                     Summary                   Location  \
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Kachiguda Railway Station
#
#                                        City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')& (h['Number_of_Rating']==5342.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       8.4
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                                  Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Kachiguda Railway Station  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.7

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent')& (h['Distance']==0.7)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# OYO 18926 Tourist Krishna Inn          2011.0   39.0       1236.0       0.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# OYO 18926 Tourist Krishna Inn     4.6             858.0  Excellent
#
#                                                 Location       City
# Name
# OYO 18926 Tourist Krishna Inn  Kachiguda Railway Station  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.5     4.8            3630.0
#
#                                     Summary                   Location  \
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Kachiguda Railway Station
#
#                                        City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3630.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3630.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.5     4.8            3630.0
#
#                                     Summary                   Location  \
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Kachiguda Railway Station
#
#                                        City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 3.5

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==3.5)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.5     4.8            3630.0
#
#                                     Summary                   Location  \
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Kachiguda Railway Station
#
#                                        City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.3    10
# 4.4    10
# 4.1     9
# 4.0     7
# 4.2     6
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       3.7     4.4             515.0
#
#                                      Summary                   Location  \
# Name
# OYO 44275 Three Castles Executive  Very Good  Kachiguda Railway Station
#
#                                         City
# Name
# OYO 44275 Three Castles Executive  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3322.0

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3322.0)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       7.1     4.4            3322.0
#
#                                       Summary                   Location  \
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good  Kachiguda Railway Station
#
#                                          City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Hyderabad

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 2.5

# %%
h[(h['Location']=='Kachiguda Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==2.5)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 16539 Grand Sandarshini Inn          3205.0   42.0       1859.0       2.5
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 16539 Grand Sandarshini Inn     4.4              56.0  Very Good
#
#                                                   Location       City
# Name
# OYO 16539 Grand Sandarshini Inn  Kachiguda Railway Station  Hyderabad

# %% [markdown]
# ## Secunderabad Railway Station

# %%
h[h['Location']=='Secunderabad Railway Station']['Summary'].value_counts()
# Out:
# Very Good               56
# Good                    33
# Excellent               29
# Fair                    15
# Yet to be summarised     6
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Secunderabad Railway Station']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Fabulous

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       2.7     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                                     Location  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Secunderabad Railway Station
#
#                                                      City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    12
# 4.6    10
# 4.7     5
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Final_price']==778)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       2.0
#
#                           Rating  Number_of_Rating    Summary  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent
#
#                                               Location       City
# Name
# OYO 49253 Raja Residency  Secunderabad Railway Station  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==5342)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       8.3
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                                     Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Secunderabad Railway Station  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.6

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Distance']==0.6)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 23543 Hotel Vaishnavi          2332.0   32.0       1590.0       0.6
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# Capital O 23543 Hotel Vaishnavi     4.5            2574.0  Excellent
#
#                                                      Location       City
# Name
# Capital O 23543 Hotel Vaishnavi  Secunderabad Railway Station  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
# Capital O 45597 Hotel Riya Grand Deluxe            3363.0   32.0       2293.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       5.5     4.8             644.0
# Capital O 45597 Hotel Riya Grand Deluxe         5.3     4.8            2628.0
#
#                                              Summary  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent
# Capital O 45597 Hotel Riya Grand Deluxe    Excellent
#
#                                                                Location  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Secunderabad Railway Station
# Capital O 45597 Hotel Riya Grand Deluxe    Secunderabad Railway Station
#
#                                                 City
# Name
# ...

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)&(h['Final_price']==1431)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       5.5     4.8             644.0
#
#                                              Summary  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent
#
#                                                                Location  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Secunderabad Railway Station
#
#                                                 City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 2628.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)&(h['Number_of_Rating']==2628)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       5.3     4.8            2628.0
#
#                                            Summary  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent
#
#                                                              Location  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Secunderabad Railway Station
#
#                                               City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)]['Distance'].min()
# Out:
# 5.3

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Excellent')&(h['Rating']==4.8)&(h['Distance']==5.3)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       5.3     4.8            2628.0
#
#                                            Summary  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent
#
#                                                              Location  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Secunderabad Railway Station
#
#                                               City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    18
# 4.3    11
# 4.1    10
# 4.2     9
# 4.0     8
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       5.8     4.4             515.0
#
#                                      Summary                      Location  \
# Name
# OYO 44275 Three Castles Executive  Very Good  Secunderabad Railway Station
#
#                                         City
# Name
# OYO 44275 Three Castles Executive  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       1.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                                     Location       City
# Name
# OYO Townhouse 064 Secunderabad  Secunderabad Railway Station  Hyderabad

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.5

# %%
h[(h['Location']=='Secunderabad Railway Station') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.5)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       1.5
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                                     Location       City
# Name
# OYO Townhouse 064 Secunderabad  Secunderabad Railway Station  Hyderabad

# %% [markdown]
# # Lb Nagar

# %%
h[h['Location']=='LB Nagar']['Summary'].value_counts()
# Out:
# Very Good               57
# Good                    33
# Excellent               28
# Fair                    15
# Yet to be summarised     6
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='LB Nagar']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Fabulous

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0      19.0     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                 Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  LB Nagar  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    12
# 4.6     9
# 4.7     5
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Final_price']==778.00)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       9.8
#
#                           Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  LB Nagar
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0      16.0
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent  LB Nagar
#
#                                      City
# Name
# OYO Flagship 15391 Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 3.9

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Distance']==3.9)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 40852 Hotel White Ridge          2014.0   32.0       1373.0       3.9
#
#                              Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 40852 Hotel White Ridge     4.6             412.0  Excellent  LB Nagar
#
#                                   City
# Name
# OYO 40852 Hotel White Ridge  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1431.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe      10.0     4.8             644.0
#
#                                              Summary  Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  LB Nagar  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 2628.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==2628.00)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe      11.0     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  LB Nagar  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 10.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==10.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe      10.0     4.8             644.0
#
#                                              Summary  Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  LB Nagar  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    18
# 4.3    11
# 4.2    10
# 4.1    10
# 4.0     8
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive      10.0     4.4             515.0
#
#                                      Summary  Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  LB Nagar  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3322.0

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3322.0)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       4.1     4.4            3322.0
#
#                                       Summary  Location       City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good  LB Nagar  Hyderabad

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 3.2

# %%
h[(h['Location']=='LB Nagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==3.2)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 18510 Hotel Sri Venkateshwara          1777.0   32.0       1212.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 18510 Hotel Sri Venkateshwara       3.2     4.4             180.0
#
#                                      Summary  Location       City
# Name
# OYO 18510 Hotel Sri Venkateshwara  Very Good  LB Nagar  Hyderabad

# %% [markdown]
# ## Kukatpally

# %%
h[h['Location']=='Kukatpally']['Summary'].value_counts()
# Out:
# Very Good               58
# Excellent               23
# Good                    21
# Fair                    10
# Yet to be summarised     8
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Kukatpally']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    12
# 4.6     6
# 4.7     4
# 4.8     1
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent') & (h['Final_price']==763.00)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       7.1
#
#                              Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Kukatpally
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==3834.00)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       3.0     4.5            3834.0
#
#                                         Summary    Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Kukatpally  Hyderabad

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.5

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent') & (h['Distance']==0.5)]
# Out:
#                                                    Original_price  Offer  \
# Name
# SilverKey Executive Stays 36044 Hanumanth Nilayam          2264.0   32.0
#
#                                                    Final_price  Distance  \
# Name
# SilverKey Executive Stays 36044 Hanumanth Nilayam       1544.0       0.5
#
#                                                    Rating  Number_of_Rating  \
# Name
# SilverKey Executive Stays 36044 Hanumanth Nilayam     4.7            1107.0
#
#                                                      Summary    Location  \
# Name
# SilverKey Executive Stays 36044 Hanumanth Nilayam  Excellent  Kukatpally
#
#                                                         City
# Name
# SilverKey Executive Stays 36044 Hanumanth Nilayam  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       7.5     4.8            3290.0
#
#                                     Summary    Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Kukatpally  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    15
# 4.0    14
# 4.3    12
# 4.2    11
# 4.1     6
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 964.0

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==964.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1479.0   35.0        964.0       9.6
#
#                               Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Kukatpally
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2028.0

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==2028.0)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe          3446.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe       2350.0       8.0     4.4
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe            2028.0  Very Good
#
#                                                 Location       City
# Name
# Capital O 12384 Hotel Serene Majestic Deluxe  Kukatpally  Hyderabad

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 4.6

# %%
h[(h['Location']=='Kukatpally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==4.6)]
# Out:
#                                                   Original_price  Offer  \
# Name
# Silverkey Executive Stays 36718 Scanda Residency          1998.0   32.0
#
#                                                   Final_price  Distance  \
# Name
# Silverkey Executive Stays 36718 Scanda Residency       1363.0       4.6
#
#                                                   Rating  Number_of_Rating  \
# Name
# Silverkey Executive Stays 36718 Scanda Residency     4.4            1395.0
#
#                                                     Summary    Location  \
# Name
# Silverkey Executive Stays 36718 Scanda Residency  Very Good  Kukatpally
#
#                                                        City
# Name
# Silverkey Executive Stays 36718 Scanda Residency  Hyderabad

# %% [markdown]
# ## Uppal

# %%
h[h['Location']=='Uppal']['Summary'].value_counts()
# Out:
# Very Good               14
# Good                    11
# Excellent                7
# Fair                     5
# Yet to be summarised     3
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Uppal']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    4
# 4.6    2
# 4.8    1
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent') & (h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       9.9     4.8            3630.0
#
#                                     Summary Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent    Uppal  Hyderabad

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3630.0

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==3630.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       9.9     4.8            3630.0
#
#                                     Summary Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent    Uppal  Hyderabad

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 6.9

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Excellent') & (h['Distance']==6.9)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       6.9
#
#                           Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent    Uppal
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.1    4
# 4.2    3
# 4.4    3
# 4.3    2
# 4.0    2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 1212.0

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==1212.00)]
# Out:
#                                         Original_price  Offer  Final_price  \
# Name
# OYO 24204 Nav Bharath Residency Deluxe          1777.0   32.0       1212.0
#
#                                         Distance  Rating  Number_of_Rating  \
# Name
# OYO 24204 Nav Bharath Residency Deluxe       9.5     4.4             423.0
#
#                                           Summary Location       City
# Name
# OYO 24204 Nav Bharath Residency Deluxe  Very Good    Uppal  Hyderabad

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3322.0

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3322.0)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       6.4     4.4            3322.0
#
#                                       Summary Location       City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good    Uppal  Hyderabad

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 6.4

# %%
h[(h['Location']=='Uppal') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==6.4)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       6.4     4.4            3322.0
#
#                                       Summary Location       City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good    Uppal  Hyderabad

# %% [markdown]
# ## Gachibowli

# %%
h[h['Location']=='Gachibowli']['Summary'].value_counts()
# Out:
# Very Good               52
# Excellent               19
# Good                    18
# Fair                     7
# Yet to be summarised     4
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Gachibowli']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    11
# 4.7     4
# 4.6     2
# 4.8     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Final_price']==763.00)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       8.3
#
#                              Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Gachibowli
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==3834.00)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       7.7     4.5            3834.0
#
#                                         Summary    Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Gachibowli  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 1.7

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Distance']==1.7)]
# Out:
#                                Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 15991 Silicon Ville          7195.0   32.0       4906.0       1.7
#
#                                Rating  Number_of_Rating    Summary  \
# Name
# Capital O 15991 Silicon Ville     4.6            1181.0  Excellent
#
#                                  Location       City
# Name
# Capital O 15991 Silicon Ville  Gachibowli  Hyderabad

# %% [markdown]
# ## Rating 4.8

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 9003 Deccan Inn Deluxe                      2830.0   32.0
# OYO 14503 Hotel Hill View Guest House Deluxe          6410.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe                   1930.0       8.5     4.8
# OYO 14503 Hotel Hill View Guest House Deluxe       4371.0       8.3     4.8
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 9003 Deccan Inn Deluxe                        3290.0  Excellent
# OYO 14503 Hotel Hill View Guest House Deluxe             166.0  Excellent
#
#                                                 Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe              Gachibowli  Hyderabad
# OYO 14503 Hotel Hill View Guest House Deluxe  Gachibowli  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')& (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1930.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Rating']==4.8)& (h['Final_price']==1930)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       8.5     4.8            3290.0
#
#                                     Summary    Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Gachibowli  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')& (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Number_of_Rating']==3290)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       8.5     4.8            3290.0
#
#                                     Summary    Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Gachibowli  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent')& (h['Rating']==4.8)]['Distance'].min()
# Out:
# 8.3

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Excellent') & (h['Distance']==8.3)]
# Out:
#                                               Original_price  Offer  \
# Name
# OYO 14503 Hotel Hill View Guest House Deluxe          6410.0   32.0
# OYO 22445 Lakshmi Residency                           2006.0   62.0
#
#                                               Final_price  Distance  Rating  \
# Name
# OYO 14503 Hotel Hill View Guest House Deluxe       4371.0       8.3     4.8
# OYO 22445 Lakshmi Residency                         763.0       8.3     4.5
#
#                                               Number_of_Rating    Summary  \
# Name
# OYO 14503 Hotel Hill View Guest House Deluxe             166.0  Excellent
# OYO 22445 Lakshmi Residency                              171.0  Excellent
#
#                                                 Location       City
# Name
# OYO 14503 Hotel Hill View Guest House Deluxe  Gachibowli  Hyderabad
# OYO 22445 Lakshmi Residency                   Gachibowli  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    15
# 4.0    14
# 4.2    11
# 4.3    10
# 4.1     2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 1010.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==1010.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1481.0   32.0       1010.0       6.8
# OYO 22074 Siri Elite                  1614.0   37.0       1010.0       4.5
#
#                               Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Gachibowli
# OYO 22074 Siri Elite             4.4            1056.0  Very Good  Gachibowli
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad
# OYO 22074 Siri Elite          Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 4550.0

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==4550.0)]
# Out:
#                                      Original_price  Offer  Final_price  \
# Name
# Capital O 13219 Sri Rama Excellency          1900.0   32.0       1296.0
#
#                                      Distance  Rating  Number_of_Rating  \
# Name
# Capital O 13219 Sri Rama Excellency       3.9     4.4            4550.0
#
#                                        Summary    Location       City
# Name
# Capital O 13219 Sri Rama Excellency  Very Good  Gachibowli  Hyderabad

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.6

# %%
h[(h['Location']=='Gachibowli') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.6)]
# Out:
#                                                     Original_price  Offer  \
# Name
# Capital O 14499 Hotel Hill View Guest House Kon...          4984.0   32.0
#
#                                                     Final_price  Distance  \
# Name
# Capital O 14499 Hotel Hill View Guest House Kon...       3398.0       1.6
#
#                                                     Rating  Number_of_Rating  \
# Name
# Capital O 14499 Hotel Hill View Guest House Kon...     4.4             670.0
#
#                                                       Summary    Location  \
# Name
# Capital O 14499 Hotel Hill View Guest House Kon...  Very Good  Gachibowli
#
#                                                          City
# Name
# Capital O 14499 Hotel Hill View Guest House Kon...  Hyderabad

# %% [markdown]
# ## Ameerpet

# %%
h[h['Location']=='Ameerpet']['Summary'].value_counts()
# Out:
# Very Good               64
# Excellent               32
# Good                    24
# Fair                    14
# Yet to be summarised     5
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Ameerpet']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Fabulous

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       5.5     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                 Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Ameerpet  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    15
# 4.6     7
# 4.7     7
# 4.8     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') &(h['Final_price']==778.00)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       6.1
#
#                           Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  Ameerpet
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') &(h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       7.6
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent  Ameerpet
#
#                                      City
# Name
# OYO Flagship 15391 Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.5

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') &(h['Distance']==0.5)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 28637 Gokul Grand          2142.0   32.0       1461.0       0.5     4.7
#
#                        Number_of_Rating    Summary  Location       City
# Name
# OYO 28637 Gokul Grand            1176.0  Excellent  Ameerpet  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1431.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       5.4     4.8             644.0
#
#                                              Summary  Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Ameerpet  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3290.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       7.8     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Ameerpet  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 4.2

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==4.2)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       4.2     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Ameerpet  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    20
# 4.3    14
# 4.2    11
# 4.1    10
# 4.0     9
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       5.8     4.4             515.0
#
#                                      Summary  Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Ameerpet  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       4.4
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good  Ameerpet
#
#                                      City
# Name
# OYO Townhouse 064 Secunderabad  Hyderabad

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 0.9

# %%
h[(h['Location']=='Ameerpet') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==0.9)]
# Out:
#                        Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 11376 Golden Park          2205.0   41.0       1311.0       0.9     4.4
#
#                        Number_of_Rating    Summary  Location       City
# Name
# OYO 11376 Golden Park            1570.0  Very Good  Ameerpet  Hyderabad

# %% [markdown]
# ## Rajiv Gandhi International Airport

# %%
h[h['Location']=='Rajiv Gandhi International Airport']['Summary'].value_counts()
# Out:
# Very Good    25
# Good          8
# Excellent     6
# Fair          1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Rajiv Gandhi International Airport']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    2
# 4.5    2
# 4.7    1
# 4.8    1
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent') &(h['Final_price']==778.0)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 60526 Hotel Green Park Suites          1140.0   32.0        778.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 60526 Hotel Green Park Suites       6.5     4.5             251.0
#
#                                      Summary  \
# Name
# OYO 60526 Hotel Green Park Suites  Excellent
#
#                                                              Location  \
# Name
# OYO 60526 Hotel Green Park Suites  Rajiv Gandhi International Airport
#
#                                         City
# Name
# OYO 60526 Hotel Green Park Suites  Hyderabad

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 815.0

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent') &(h['Number_of_Rating']==815)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 35467 Shiridi Residency          1403.0   32.0        957.0      17.0
#
#                              Rating  Number_of_Rating    Summary  \
# Name
# OYO 35467 Shiridi Residency     4.7             815.0  Excellent
#
#                                                        Location       City
# Name
# OYO 35467 Shiridi Residency  Rajiv Gandhi International Airport  Hyderabad

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 6.5

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent') &(h['Distance']==6.5)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 60526 Hotel Green Park Suites          1140.0   32.0        778.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 60526 Hotel Green Park Suites       6.5     4.5             251.0
#
#                                      Summary  \
# Name
# OYO 60526 Hotel Green Park Suites  Excellent
#
#                                                              Location  \
# Name
# OYO 60526 Hotel Green Park Suites  Rajiv Gandhi International Airport
#
#                                         City
# Name
# OYO 60526 Hotel Green Park Suites  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe      17.0     4.8             644.0
#
#                                              Summary  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent
#
#                                                                      Location  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Rajiv Gandhi International Airport
#
#                                                 City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    8
# 4.2    7
# 4.1    4
# 4.3    4
# 4.0    2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 789.0

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==789.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13636 Sri Vinayaka Grand          1417.0   44.0        789.0       5.3
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 13636 Sri Vinayaka Grand     4.4             259.0  Very Good
#
#                                                         Location       City
# Name
# OYO 13636 Sri Vinayaka Grand  Rajiv Gandhi International Airport  Hyderabad

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1913.0

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==1913.0)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar          2530.0   32.0       1725.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar      18.0     4.4            1913.0
#
#                                            Summary  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar  Very Good
#
#                                                                    Location  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar  Rajiv Gandhi International Airport
#
#                                               City
# Name
# OYO Townhouse 113 Green Leaves LB Nagar  Hyderabad

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 5.3

# %%
h[(h['Location']=='Rajiv Gandhi International Airport') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==5.3)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13636 Sri Vinayaka Grand          1417.0   44.0        789.0       5.3
#
#                               Rating  Number_of_Rating    Summary  \
# Name
# OYO 13636 Sri Vinayaka Grand     4.4             259.0  Very Good
#
#                                                         Location       City
# Name
# OYO 13636 Sri Vinayaka Grand  Rajiv Gandhi International Airport  Hyderabad

# %% [markdown]
# ## Lakdikapool

# %%
h[h['Location']=='Lakdikapool']['Summary'].value_counts()
# Out:
# Very Good               65
# Good                    38
# Excellent               32
# Fair                    15
# Yet to be summarised     9
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Lakdikapool']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Fabulous

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       8.9     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                    Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Lakdikapool  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    13
# 4.6    10
# 4.7     6
# 4.8     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') &(h['Final_price']==778.00)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       4.5
#
#                           Rating  Number_of_Rating    Summary     Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  Lakdikapool
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') &(h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       3.7
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                    Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Lakdikapool  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.4

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') &(h['Distance']==0.4)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       0.4     4.8            2628.0
#
#                                            Summary     Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Lakdikapool  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1431.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       2.2     4.8             644.0
#
#                                              Summary     Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Lakdikapool  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 2628.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==2628.00)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       0.4     4.8            2628.0
#
#                                            Summary     Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Lakdikapool  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 0.4

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==0.4)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       0.4     4.8            2628.0
#
#                                            Summary     Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Lakdikapool  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    20
# 4.3    16
# 4.1    11
# 4.2    10
# 4.0     8
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       1.3     4.4             515.0
#
#                                      Summary     Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Lakdikapool  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3057.0

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3057.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Townhouse 064 Secunderabad          4994.0   32.0       3405.0       5.3
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Townhouse 064 Secunderabad     4.4            3057.0  Very Good
#
#                                    Location       City
# Name
# OYO Townhouse 064 Secunderabad  Lakdikapool  Hyderabad

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.3

# %%
h[(h['Location']=='Lakdikapool') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.3)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       1.3     4.4             515.0
#
#                                      Summary     Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Lakdikapool  Hyderabad

# %% [markdown]
# ## Shamshabad

# %%
h[h['Location']=='Shamshabad']['Summary'].value_counts()
# Out:
# Very Good               22
# Good                    11
# Excellent                5
# Yet to be summarised     1
# Fair                     1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Shamshabad']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')]
# Out:
#                                              Original_price  Offer  \
# Name
# OYO 60526 Hotel Green Park Suites                    1140.0   32.0
# Capital O 46832 Gaayatri Residency Deluxe            2098.0   32.0
# Capital O 29894 Royal Emirates                       2835.0   32.0
# OYO 46837 Vivid Stay Near Sunshine Hospital          1777.0   32.0
# OYO 49253 Raja Residency                             1140.0   32.0
#
#                                              Final_price  Distance  Rating  \
# Name
# OYO 60526 Hotel Green Park Suites                  778.0       9.8     4.5
# Capital O 46832 Gaayatri Residency Deluxe         1431.0      16.0     4.8
# Capital O 29894 Royal Emirates                    1933.0      18.0     4.7
# OYO 46837 Vivid Stay Near Sunshine Hospital       1212.0      19.0     4.5
# OYO 49253 Raja Residency                           778.0      19.0     4.5
#
#                                              Number_of_Rating    Summary  \
# Name
# ...

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')&(h['Final_price']==778.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 60526 Hotel Green Park Suites          1140.0   32.0        778.0
# OYO 49253 Raja Residency                   1140.0   32.0        778.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 60526 Hotel Green Park Suites       9.8     4.5             251.0
# OYO 49253 Raja Residency               19.0     4.5             162.0
#
#                                      Summary    Location       City
# Name
# OYO 60526 Hotel Green Park Suites  Excellent  Shamshabad  Hyderabad
# OYO 49253 Raja Residency           Excellent  Shamshabad  Hyderabad

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 1845.0

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==1845.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 29894 Royal Emirates          2835.0   32.0       1933.0      18.0
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# Capital O 29894 Royal Emirates     4.7            1845.0  Excellent
#
#                                   Location       City
# Name
# Capital O 29894 Royal Emirates  Shamshabad  Hyderabad

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 9.8

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Excellent')&(h['Distance']==9.8)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 60526 Hotel Green Park Suites          1140.0   32.0        778.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 60526 Hotel Green Park Suites       9.8     4.5             251.0
#
#                                      Summary    Location       City
# Name
# OYO 60526 Hotel Green Park Suites  Excellent  Shamshabad  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    6
# 4.1    5
# 4.2    5
# 4.3    4
# 4.0    2
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 789.0

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==789.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13636 Sri Vinayaka Grand          1417.0   44.0        789.0       5.8
#
#                               Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 13636 Sri Vinayaka Grand     4.4             259.0  Very Good  Shamshabad
#
#                                    City
# Name
# OYO 13636 Sri Vinayaka Grand  Hyderabad

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 1913.0

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==1913.0)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar          2530.0   32.0       1725.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# OYO Townhouse 113 Green Leaves LB Nagar      16.0     4.4            1913.0
#
#                                            Summary    Location       City
# Name
# OYO Townhouse 113 Green Leaves LB Nagar  Very Good  Shamshabad  Hyderabad

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 5.8

# %%
h[(h['Location']=='Shamshabad') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==5.8)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 13636 Sri Vinayaka Grand          1417.0   44.0        789.0       5.8
#
#                               Rating  Number_of_Rating    Summary    Location  \
# Name
# OYO 13636 Sri Vinayaka Grand     4.4             259.0  Very Good  Shamshabad
#
#                                    City
# Name
# OYO 13636 Sri Vinayaka Grand  Hyderabad

# %% [markdown]
# ## Himayathnagar

# %%
h[h['Location']=='Himayathnagar']['Summary'].value_counts()
# Out:
# Very Good               57
# Good                    33
# Excellent               29
# Fair                    12
# Yet to be summarised     8
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Himayathnagar']['Summary'].value_counts().plot.bar()

# %% [markdown]
# # Fabulous

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       7.2     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                      Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Himayathnagar  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    11
# 4.5    11
# 4.7     4
# 4.8     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.1     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       7.1
#
#                                 Rating  Number_of_Rating    Summary  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent
#
#                                      Location       City
# Name
# OYO Flagship 15391 Mehdipatnam  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.2

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent')&(h['Distance']==0.2)]
# Out:
#                          Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 9960 Kubeera Palace          3097.0   32.0       2112.0       0.2     4.5
#
#                          Number_of_Rating    Summary       Location       City
# Name
# OYO 9960 Kubeera Palace             855.0  Excellent  Himayathnagar  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
# SPOT ON 37214 Classic Lodge SPOT                    826.0   32.0        563.0
# Capital O 45597 Hotel Riya Grand Deluxe            3363.0   32.0       2293.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       2.5     4.8             644.0
# SPOT ON 37214 Classic Lodge SPOT                3.1     4.8            3630.0
# Capital O 45597 Hotel Riya Grand Deluxe         3.0     4.8            2628.0
#
#                                              Summary       Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Himayathnagar  Hyderabad
# SPOT ON 37214 Classic Lodge SPOT           Excellent  Himayathnagar  Hyderabad
# Capital O 45597 Hotel Riya Grand Deluxe    Excellent  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 563.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==563.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.1     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3630.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3630.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# SPOT ON 37214 Classic Lodge SPOT           826.0   32.0        563.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# SPOT ON 37214 Classic Lodge SPOT       3.1     4.8            3630.0
#
#                                     Summary       Location       City
# Name
# SPOT ON 37214 Classic Lodge SPOT  Excellent  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 2.5

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==2.5)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       2.5     4.8             644.0
#
#                                              Summary       Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Himayathnagar  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    16
# 4.3    13
# 4.1    10
# 4.2     9
# 4.0     9
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       3.2     4.4             515.0
#
#                                      Summary       Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3322.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3322.0)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       9.2     4.4            3322.0
#
#                                       Summary       Location       City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good  Himayathnagar  Hyderabad

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 1.0

# %%
h[(h['Location']=='Himayathnagar') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==1.0)]
# Out:
#                                  Original_price  Offer  Final_price  Distance  \
# Name
# OYO 16857 Hotel Jp Plaza Deluxe          2267.0   32.0       1546.0       1.0
#
#                                  Rating  Number_of_Rating    Summary  \
# Name
# OYO 16857 Hotel Jp Plaza Deluxe     4.4             381.0  Very Good
#
#                                       Location       City
# Name
# OYO 16857 Hotel Jp Plaza Deluxe  Himayathnagar  Hyderabad

# %% [markdown]
# ## Madhapur

# %%
h[h['Location']=='Madhapur']['Summary'].value_counts()
# Out:
# Very Good               67
# Good                    28
# Excellent               27
# Fair                    10
# Yet to be summarised     8
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Madhapur']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    13
# 4.6     7
# 4.7     4
# 4.8     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')&(h['Final_price']==763.00)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       8.5
#
#                              Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Madhapur
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==3834.00)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       5.4     4.5            3834.0
#
#                                         Summary  Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Madhapur  Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.8

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent')&(h['Distance']==0.8)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       0.8     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Madhapur  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]
# Out:
#                                               Original_price  Offer  \
# Name
# Capital O 9003 Deccan Inn Deluxe                      2830.0   32.0
# Capital O 45597 Hotel Riya Grand Deluxe               3363.0   32.0
# OYO 14503 Hotel Hill View Guest House Deluxe          6410.0   32.0
#
#                                               Final_price  Distance  Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe                   1930.0       0.8     4.8
# Capital O 45597 Hotel Riya Grand Deluxe            2293.0       9.5     4.8
# OYO 14503 Hotel Hill View Guest House Deluxe       4371.0       5.1     4.8
#
#                                               Number_of_Rating    Summary  \
# Name
# Capital O 9003 Deccan Inn Deluxe                        3290.0  Excellent
# Capital O 45597 Hotel Riya Grand Deluxe                 2628.0  Excellent
# OYO 14503 Hotel Hill View Guest House Deluxe             166.0  Excellent
#
#                                               Location       City
# ...

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1930.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1930.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       0.8     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Madhapur  Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 3290.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==3290.00)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       0.8     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Madhapur  Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 0.8

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==0.8)]
# Out:
#                                   Original_price  Offer  Final_price  \
# Name
# Capital O 9003 Deccan Inn Deluxe          2830.0   32.0       1930.0
#
#                                   Distance  Rating  Number_of_Rating  \
# Name
# Capital O 9003 Deccan Inn Deluxe       0.8     4.8            3290.0
#
#                                     Summary  Location       City
# Name
# Capital O 9003 Deccan Inn Deluxe  Excellent  Madhapur  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    21
# 4.0    16
# 4.3    14
# 4.2    10
# 4.1     6
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 1010.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==1010.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1481.0   32.0       1010.0       5.7
# OYO 22074 Siri Elite                  1614.0   37.0       1010.0       3.1
#
#                               Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Madhapur
# OYO 22074 Siri Elite             4.4            1056.0  Very Good  Madhapur
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad
# OYO 22074 Siri Elite          Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2104.0

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==2104.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37516 Apple Tree Inn          3344.0   32.0       2280.0       8.3
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# Capital O 37516 Apple Tree Inn     4.4            2104.0  Very Good  Madhapur
#
#                                      City
# Name
# Capital O 37516 Apple Tree Inn  Hyderabad

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 0.4

# %%
h[(h['Location']=='Madhapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==0.4)]
# Out:
#                   Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 13671 Qualia          2151.0   32.0       1467.0       0.4     4.4
#
#                   Number_of_Rating    Summary  Location       City
# Name
# OYO 13671 Qualia             496.0  Very Good  Madhapur  Hyderabad

# %% [markdown]
# ## Miyapur

# %%
h[h['Location']=='Miyapur']['Summary'].value_counts()
# Out:
# Very Good               35
# Good                    15
# Excellent               14
# Fair                     9
# Yet to be summarised     7
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Miyapur']['Summary'].value_counts().plot.bar()

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.5    8
# 4.7    3
# 4.6    3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 763.0

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent') &(h['Final_price']==763.00)]
# Out:
#                              Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22445 Lakshmi Residency          2006.0   62.0        763.0       6.3
#
#                              Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 22445 Lakshmi Residency     4.5             171.0  Excellent  Miyapur
#
#                                   City
# Name
# OYO 22445 Lakshmi Residency  Hyderabad

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 3834.0

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent') &(h['Number_of_Rating']==3834.00)]
# Out:
#                                       Original_price  Offer  Final_price  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally          2641.0   32.0       1801.0
#
#                                       Distance  Rating  Number_of_Rating  \
# Name
# OYO 41729 Elite Stay JNTU Kukatpally       4.4     4.5            3834.0
#
#                                         Summary Location       City
# Name
# OYO 41729 Elite Stay JNTU Kukatpally  Excellent  Miyapur  Hyderabad

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 2.3

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Excellent') &(h['Distance']==2.3)]
# Out:
#                       Original_price  Offer  Final_price  Distance  Rating  \
# Name
# OYO 10596 Hotel Indu          1967.0   32.0       1342.0       2.3     4.6
#
#                       Number_of_Rating    Summary Location       City
# Name
# OYO 10596 Hotel Indu             654.0  Excellent  Miyapur  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    10
# 4.0    10
# 4.2     6
# 4.3     6
# 4.1     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 964.0

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==964.00)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1479.0   35.0        964.0       5.3
#
#                               Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Miyapur
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 2104.0

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==2104.0)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# Capital O 37516 Apple Tree Inn          3344.0   32.0       2280.0       7.6
#
#                                 Rating  Number_of_Rating    Summary Location  \
# Name
# Capital O 37516 Apple Tree Inn     4.4            2104.0  Very Good  Miyapur
#
#                                      City
# Name
# Capital O 37516 Apple Tree Inn  Hyderabad

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 5.3

# %%
h[(h['Location']=='Miyapur') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==5.3)]
# Out:
#                               Original_price  Offer  Final_price  Distance  \
# Name
# OYO 22425 Hotel Honey Cruise          1479.0   35.0        964.0       5.3
#
#                               Rating  Number_of_Rating    Summary Location  \
# Name
# OYO 22425 Hotel Honey Cruise     4.4            1014.0  Very Good  Miyapur
#
#                                    City
# Name
# OYO 22425 Hotel Honey Cruise  Hyderabad

# %% [markdown]
# ## Nampally

# %%
h[h['Location']=='Nampally']['Summary'].value_counts()
# Out:
# Very Good               60
# Good                    31
# Excellent               29
# Fair                    12
# Yet to be summarised     7
# Fabulous                 1
# Name: Summary, dtype: int64

# %%
h[h['Location']=='Nampally']['Summary'].value_counts().plot.bar()

# %% [markdown]
# # Fabulous

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Fabulous')]
# Out:
#                                                 Original_price  Offer  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet          2087.0   32.0
#
#                                                 Final_price  Distance  Rating  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet       1423.0       9.2     4.9
#
#                                                 Number_of_Rating   Summary  \
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet             299.0  Fabulous
#
#                                                 Location       City
# Name
# OYO 14501 Hotel Hill View Guest House Begumpet  Nampally  Hyderabad

# %% [markdown]
# ## Excellent

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')]['Rating'].value_counts()
# Out:
# 4.6    10
# 4.5    10
# 4.7     6
# 4.8     3
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')]['Final_price'].min()
# Out:
# 778.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')&(h['Final_price']==778.00)]
# Out:
#                           Original_price  Offer  Final_price  Distance  \
# Name
# OYO 49253 Raja Residency          1140.0   32.0        778.0       4.9
#
#                           Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 49253 Raja Residency     4.5             162.0  Excellent  Nampally
#
#                                City
# Name
# OYO 49253 Raja Residency  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')]['Number_of_Rating'].max()
# Out:
# 5342.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')&(h['Number_of_Rating']==5342.00)]
# Out:
#                                 Original_price  Offer  Final_price  Distance  \
# Name
# OYO Flagship 15391 Mehdipatnam          2121.0   43.0       1212.0       4.1
#
#                                 Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO Flagship 15391 Mehdipatnam     4.5            5342.0  Excellent  Nampally
#
#                                      City
# Name
# OYO Flagship 15391 Mehdipatnam  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')]['Distance'].min()
# Out:
# 0.9

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent')&(h['Distance']==0.9)]
# Out:
#                             Original_price  Offer  Final_price  Distance  \
# Name
# OYO 16061 Hotel Holly Hock          2601.0   32.0       1774.0       0.9
#
#                             Rating  Number_of_Rating    Summary  Location  \
# Name
# OYO 16061 Hotel Holly Hock     4.6             716.0  Excellent  Nampally
#
#                                  City
# Name
# OYO 16061 Hotel Holly Hock  Hyderabad

# %% [markdown]
# ## Rating = 4.8

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Final_price'].min()
# Out:
# 1431.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Final_price']==1431.00)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       1.0     4.8             644.0
#
#                                              Summary  Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Nampally  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Number_of_Rating'].max()
# Out:
# 2628.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Number_of_Rating']==2628.00)]
# Out:
#                                          Original_price  Offer  Final_price  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe          3363.0   32.0       2293.0
#
#                                          Distance  Rating  Number_of_Rating  \
# Name
# Capital O 45597 Hotel Riya Grand Deluxe       1.9     4.8            2628.0
#
#                                            Summary  Location       City
# Name
# Capital O 45597 Hotel Riya Grand Deluxe  Excellent  Nampally  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)]['Distance'].min()
# Out:
# 1.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Excellent') & (h['Rating']==4.8)&(h['Distance']==1.0)]
# Out:
#                                            Original_price  Offer  Final_price  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe          2098.0   32.0       1431.0
#
#                                            Distance  Rating  Number_of_Rating  \
# Name
# Capital O 46832 Gaayatri Residency Deluxe       1.0     4.8             644.0
#
#                                              Summary  Location       City
# Name
# Capital O 46832 Gaayatri Residency Deluxe  Excellent  Nampally  Hyderabad

# %% [markdown]
# ### Very Good

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good')]['Rating'].value_counts()
# Out:
# 4.4    19
# 4.3    15
# 4.2     9
# 4.1     9
# 4.0     8
# Name: Rating, dtype: int64

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good')]['Rating'].value_counts().plot.bar()

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Final_price'].min()
# Out:
# 795.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Final_price']==795.00)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       0.7     4.4             515.0
#
#                                      Summary  Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Nampally  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Number_of_Rating'].max()
# Out:
# 3322.0

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Number_of_Rating']==3322.0)]
# Out:
#                                     Original_price  Offer  Final_price  \
# Name
# OYO Flagship 16073 Kothapet Ramoji          3597.0   32.0       2452.0
#
#                                     Distance  Rating  Number_of_Rating  \
# Name
# OYO Flagship 16073 Kothapet Ramoji       8.3     4.4            3322.0
#
#                                       Summary  Location       City
# Name
# OYO Flagship 16073 Kothapet Ramoji  Very Good  Nampally  Hyderabad

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)]['Distance'].min()
# Out:
# 0.7

# %%
h[(h['Location']=='Nampally') & (h['Summary']=='Very Good') & (h['Rating']==4.4)&(h['Distance']==0.7)]
# Out:
#                                    Original_price  Offer  Final_price  \
# Name
# OYO 44275 Three Castles Executive          1166.0   32.0        795.0
#
#                                    Distance  Rating  Number_of_Rating  \
# Name
# OYO 44275 Three Castles Executive       0.7     4.4             515.0
#
#                                      Summary  Location       City
# Name
# OYO 44275 Three Castles Executive  Very Good  Nampally  Hyderabad
