# %%
import numpy as np
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['Mumbai',
#  'Bangalore',
#  'Hyderabad.csv',
#  'Delhi.csv',
#  '.DS_Store',
#  'Chennai.csv',
#  'Mumbai.csv',
#  'Hyderabad',
#  'Chennai',
#  'Delhi',
#  'Bangalore.csv',
#  'Final_Dataset.ipynb',
#  '.ipynb_checkpoints']

# %%
df1=pd.read_csv('Hyderabad.csv')
df2=pd.read_csv('Bangalore.csv')
df3=pd.read_csv('Chennai.csv')
df4=pd.read_csv('Mumbai.csv')
df5=pd.read_csv('Delhi.csv')

# %%
df=pd.DataFrame()

# %%
df=df.append(df1,sort=False)
df=df.append(df2,sort=False)
df=df.append(df3,sort=False)
df=df.append(df4,sort=False)
df=df.append(df5,sort=False)

# %%
df
# Out:
#                                                    Name Original_price  \
# 0                     OYO 22085 Raj Banjara White House          ₹2459
# 1                       Collection O 42514 Venkat Nagar          ₹3158
# 2                Capital O 44354 Jubilee Banjara Suites          ₹1778
# 3                           OYO 35487 Hotel Meena Grand          ₹2090
# 4                             OYO 16018 Rainbow Saphire          ₹2607
# 5                   Collection O 46198 New Sree Krishna          ₹3964
# 6                           OYO 14224 Happy Guest house          ₹2373
# 7                         OYO 62547 Dream Connect Stays          ₹1941
# 8                                 OYO 11376 Golden Park          ₹2205
# 9                                 OYO 11316 Athithi Inn          ₹2178
# 10                                 OYO 10272 Hotel Ruma          ₹1777
# 11                                   OYO 18725 Sr Grand          ₹1910
# ...

# %%
df.to_csv('Final_Dataset.csv',index=False,header=True)
